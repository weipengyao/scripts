# %%
import os.path
import dataAnalysisUtil
import numpy as np
import yt
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import matplotlib
import astropy
import pickle

# %%
dataAnalysisUtil.init()

# %%
filedir  = '/Users/yao/Desktop/Data/job.98632/'
filename = 'lasslab_hdf5_plt_cnt_0001'
file = dataAnalysisUtil.loadup(filedir + filename)
# Out:
# yt : [WARNING  ] 2025-03-12 15:19:58,511 Extending theta dimension to 2PI + left edge.
# yt : [INFO     ] 2025-03-12 15:19:58,544 Parameters: current_time              = 1.0005015319950047e-09
# yt : [INFO     ] 2025-03-12 15:19:58,544 Parameters: domain_dimensions         = [128 256   1]
# yt : [INFO     ] 2025-03-12 15:19:58,545 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-12 15:19:58,545 Parameters: domain_right_edge         = [1.         4.         6.28318531]
# yt : [INFO     ] 2025-03-12 15:19:58,546 Parameters: cosmological_simulation   = 0
# Loaded up /Users/yao/Desktop/Data/job.98632/lasslab_hdf5_plt_cnt_0001

# %%
atomic_mass = 4

# %%
data,axisLabels,name,colormap,title,interpolation,ext = dataAnalysisUtil.plot2DDS(
    file, 2, 0.0, 'full domain', field='dens', 
    logScale=True
)
# Out:
# yt : [INFO     ] 2025-03-12 15:21:43,220 Making a fixed resolution buffer of (dens) 1024 by 512
# This may take a few moments
# Generating slice along axis 2
# Generating fixed resolution buffer
# Returning Numpy array
# Full domain for 2 is:  [unyt_quantity(0., 'code_length'), unyt_quantity(1., 'code_length'), unyt_quantity(0., 'code_length'), unyt_quantity(4., 'code_length')]
# Fetching units for field
# Loading up data as numpy array
# Setting color map to  DEFAULT
# Setting axes
# Setting title
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data,axisLabels,name,colormap,title,interpolation,ext = dataAnalysisUtil.plot2DDS(
#       2     file, 2, 0.0, 'full domain', field='dens',
#       3     logScale=True
#       4 )
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
data, axisLabels,name,colormap,title,interpolation,ext = dataAnalysisUtil.plot2DDS(
    file, 2, 0.0, 'full domain', field='tele', 
    # logScale=True
)
# Out:
# This may take a few moments
# Generating slice along axis 2
# Generating fixed resolution buffer
# Returning Numpy array
# Full domain for 2 is:  [unyt_quantity(0., 'code_length'), unyt_quantity(0.5, 'code_length'), unyt_quantity(0., 'code_length'), unyt_quantity(1., 'code_length')]
# Fetching units for field
# Loading up data as numpy array
# Setting color map to  DEFAULT
# Setting axes
# Setting title
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 data, axisLabels,name,colormap,title,interpolation,ext = dataAnalysisUtil.plot2DDS(
#       2     file, 2, 0.0, 'full domain', field='tele',
#       3     # logScale=True
#       4 )
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
a = np.array(data)

# %%
a
# Out:
# array(None, dtype=object)
