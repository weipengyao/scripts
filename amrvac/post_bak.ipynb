# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.gridspec as gridspec

# %%
import yt

# %%
import astropy

# %%
print(yt.__version__)
# Out:
# 4.4.1

# %%
from yt.frontends.amrvac.datfile_utils import get_header
with open("/Users/yao/Desktop/dataloadtest/test_0195.dat","rb") as f:
    hdr = get_header(f)
print(hdr)  # should show ndim, nvar, block counts, etc.
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[5], line 3
#       1 from yt.frontends.amrvac.datfile_utils import get_header
#       2 with open("/Users/yao/Desktop/dataloadtest/test_0195.dat","rb") as f:
# ----> 3     hdr = get_header(f)
#       4 print(hdr)  # should show ndim, nvar, block counts, etc.
#
# File ~/scripts/.venv/lib/python3.12/site-packages/yt/frontends/amrvac/datfile_utils.py:29, in get_header(istream)
#      26 [h["datfile_version"]] = struct.unpack(fmt, istream.read(struct.calcsize(fmt)))
#      28 if h["datfile_version"] < 3:
# ---> 29     raise OSError("Unsupported AMRVAC .dat file version: %d", h["datfile_version"])
#      31 # Read scalar data at beginning of file
#      32 fmt = ALIGN + 9 * "i" + "d"
#
# OSError: [Errno Unsupported AMRVAC .dat file version: %d] -187484786

# %%
yt.load_uniform_grid('/Users/yao/Documents/Data/AMRVAC/test2/test_0195.dat'
                    #  ,domain_dimensions=
                     )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 yt.load_uniform_grid('/Users/yao/Documents/Data/AMRVAC/test2/test_0195.dat'
#       2                     #  ,domain_dimensions=
#       3                      )
#
# TypeError: load_uniform_grid() missing 1 required positional argument: 'domain_dimensions'

# %%
ds = yt.load("/Users/yao/Desktop/dataloadtest/test_0195.dat")
# Out:
# ---------------------------------------------------------------------------
# YTUnidentifiedDataType                    Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ds = yt.load("/Users/yao/Desktop/dataloadtest/test_0195.dat")
#
# File ~/scripts/.venv/lib/python3.12/site-packages/yt/_maintenance/deprecation.py:68, in future_positional_only.<locals>.outer.<locals>.inner(*args, **kwargs)
#      59     value = kwargs[name]
#      60     issue_deprecation_warning(
#      61         f"Using the {name!r} argument as keyword (on position {no}) "
#      62         "is deprecated. "
#    (...)     66         **depr_kwargs,
#      67     )
# ---> 68 return func(*args, **kwargs)
#
# File ~/scripts/.venv/lib/python3.12/site-packages/yt/loaders.py:146, in load(fn, hint, *args, **kwargs)
#     143 if len(candidates) > 1:
#     144     raise YTAmbiguousDataType(_input_fn, candidates)
# --> 146 raise YTUnidentifiedDataType(_input_fn, *args, **kwargs)
#
# YTUnidentifiedDataType: Could not determine input format from '/Users/yao/Desktop/dataloadtest/test_0195.dat'
# Please make sure you are running a sufficiently recent version of yt.

# %%
# x, y, b1, b2, b3 = np.loadtxt('/Users/yao/Documents/Data/AMRVAC/test1/visit_b1_b2_b3_0010.xyz',
#                         unpack=True,skiprows=2,usecols=[1,2,4,5,6])

x, y, b1, b2, b3 = np.loadtxt('/Users/yao/Desktop/test_0013.blk',
                        unpack=True,skiprows=2,usecols=[0,1,7,8,9])

# %%
xu = np.unique(x)
yu = np.unique(y)

# %%
yu.shape
# Out:
# (600,)

# %%
xi = np.searchsorted(np.unique(x), x)
yj = np.searchsorted(np.unique(y), y)

# %%
yj
# Out:
# array([  7,   7,   7, ..., 592, 592, 592], shape=(274800,))

# %%
def grid_data(x, y, data, Nx, Ny):
    xi = np.searchsorted(np.unique(x), x)
    yj = np.searchsorted(np.unique(y), y)
    flat_idx = xi * Ny + yj
    order = np.argsort(flat_idx)
    flat_idx = flat_idx[order]
    uniq_flat, start_idx, counts = np.unique(flat_idx, return_index=True, return_counts=True)
    data_sorted = data[order]
    data_sum = np.add.reduceat(data_sorted, start_idx)
    data_mean = data_sum / counts
    data_grid = np.full((Nx, Ny), np.nan)
    ii = uniq_flat // Ny
    jj = uniq_flat % Ny
    data_grid[ii, jj] = data_mean
    return data_grid

# %%
xu = np.unique(x)
yu = np.unique(y)
Nx, Ny = xu.size, yu.size

b1_grid = grid_data(x, y, b1, Nx, Ny)
b2_grid = grid_data(x, y, b2, Nx, Ny)
b3_grid = grid_data(x, y, b3, Nx, Ny)

# %%
x_grid = grid_data(x, y, x, Nx, Ny)
y_grid = grid_data(x, y, y, Nx, Ny)

# %%
x_grid.shape
# Out:
# (1000, 600)

# %%
xmin = np.min(x)
xmax = np.max(x)
ymin = np.min(y)
ymax = np.max(y)

# %%
plt.imshow(b1_grid.T, 
           origin='lower', 
           extent=(xmin, xmax, ymin, ymax), 
           cmap='jet',
           aspect='auto')
plt.colorbar(label='Bx')

# %%
# Converting simulation units to physical units
mpCGS=1.67e-24                          # g
vA=1e-4*3.0e10                          # cm/s
ni=0.002                                 # cm^-3
B0=vA*np.sqrt(4.0*np.pi*ni*mpCGS)*1.0e6 # uG
print('Field strength of the ordered field = %.2e uG' % B0)
# Out:
# Field strength of the ordered field = 6.15e-01 uG

# %%
fs = 12

# Plot components of B-field 
def plot_compB(x, y, B1, B2, B3, i_comp):

    # Extent of simulation domains in unit of rg of simulated particles
    xmin=np.min(x)
    xmax=np.max(x)
    ymin=np.min(y)
    ymax=np.max(y)


    # Plot components of B-field
    fig, ax=plt.subplots(figsize=(10,4.5))
    if(i_comp==1):
        im=ax.imshow(B1[:,:].T, extent=[xmin, xmax, ymin, ymax], origin='lower', cmap='magma')#, vmin=-200, vmax=200)
        ax.set_title(r'$B_1(x,y)$', fontsize=fs)
    if(i_comp==2):
        im=ax.imshow(B2[:,:].T, extent=[xmin, xmax, ymin, ymax], origin='lower', cmap='magma')#, vmin=-200, vmax=200)
        ax.set_title(r'$B_2(x,y)$', fontsize=fs)
    if(i_comp==3):
        im=ax.imshow(B3[:,:].T, extent=[xmin, xmax, ymin, ymax], origin='lower', cmap='magma')#, vmin=-200, vmax=200)
        ax.set_title(r'$B_3(x,y)$', fontsize=fs)

    ax.set_xlabel(r'$x/r_{\rm CR}$', fontsize=fs)
    ax.set_ylabel(r'$y/r_{\rm CR}$', fontsize=fs)
    ax.tick_params(axis='x', labelsize=fs)
    ax.tick_params(axis='y', labelsize=fs)
    # ax.set_xlim(-40,40)
    # ax.set_ylim(-20,20)
    # ax.set_title(r'$\Omega_0 t=%d$, %s' % (step*10, sim_name), fontsize=fs+2, x=0.01, y=0.98, ha='left')

    divider = make_axes_locatable(ax)
    cax = divider.append_axes("right", size="5%", pad=0.1)
    plt.colorbar(im, cax=cax).ax.tick_params(labelsize=fs)    
    # plt.savefig('Results_%s/fg_compB%d_%s_%d.png' % (sim_name, i_comp, sim_name, step))
    # plt.close()

# %%
plot_compB(x, y, b1_grid, b2_grid, b3_grid, 1)

# %%
def print_nan(a):
    # Boolean mask of NaN positions
    mask = np.isnan(a)
    print(mask)
    # [False  True False False]

    # Check if there is at least one NaN
    print(np.any(mask))
    # True

    # Count how many NaNs
    print('There is ', np.sum(mask), 'of NaNs out of an array of size:', a.size)
    # 1

    # Get indices of NaNs
    print(np.where(mask))
    # (array([1]),)
    return 0

# %%
kx=(np.fft.fftshift(np.fft.fftfreq(Nx,(xmax-xmin)/Nx)))*2.0*np.pi
ky=(np.fft.fftshift(np.fft.fftfreq(Ny,(ymax-ymin)/Ny)))*2.0*np.pi
kxmin=np.min(kx)
kxmax=np.max(kx)
kymin=np.min(ky)
kymax=np.max(ky)

print(kxmin, kxmax, kymin, kymax)
# Out:
# -43.81579712119655 43.728165526954164 -157.57204532111814 157.04680517004778

# %%
mask = (xu >= -5) & (xu <= 10)
b1_new = b1_grid[mask,:]
b2_new = b2_grid[mask,:]
b3_new = b3_grid[mask,:]
x_new = x_grid[mask,:]
y_new = y_grid[mask,:]

# b1_new = np.where()

# print(mask)
# print(b1_new.shape)
# print(b1_grid.shape)

# %%
xmin = np.min(x_new)
xmax = np.max(x_new)
ymin = np.min(y)
ymax = np.max(y)

# %%
b1_new
# Out:
# array([[0.00898889,        nan, 0.0089915 , ..., 0.00899501,        nan,
#         0.00899111],
#        [0.00898745,        nan, 0.00899054, ..., 0.00899187,        nan,
#         0.00898788],
#        [0.00898836,        nan, 0.0089893 , ..., 0.00898848,        nan,
#         0.00898693],
#        ...,
#        [0.00894707,        nan, 0.00902613, ..., 0.00893532,        nan,
#         0.00889132],
#        [0.00894515,        nan, 0.00902886, ..., 0.0089474 ,        nan,
#         0.0088934 ],
#        [0.0089439 ,        nan, 0.00902954, ..., 0.00894894,        nan,
#         0.00889564]], shape=(400, 600))

# %%
plt.imshow(b1_new.T, 
           origin='lower', 
           extent=(xmin, xmax, ymin, ymax), 
           cmap='jet',
           aspect='auto')
plt.colorbar(label='Bx')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 plt.imshow(b1_new.T,
#       2            origin='lower',
#       3            extent=(xmin, xmax, ymin, ymax),
#       4            cmap='jet',
#       5            aspect='auto')
#       6 plt.colorbar(label='Bx')
#
# File ~/scripts/.venv/lib/python3.12/site-packages/matplotlib/pyplot.py:3601, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3579 @_copy_docstring_and_deprecators(Axes.imshow)
#    3580 def imshow(
#    3581     X: ArrayLike | PIL.Image.Image,
#    (...)   3599     **kwargs,
#    3600 ) -> AxesImage:
# -> 3601     __ret = gca().imshow(
#    3602         X,
#    3603         cmap=cmap,
#    3604         norm=norm,
#    3605         aspect=aspect,
#    3606         interpolation=interpolation,
#    3607         alpha=alpha,
#    3608         vmin=vmin,
#    3609         vmax=vmax,
#    3610         colorizer=colorizer,
#    3611         origin=origin,
#    3612         extent=extent,
#    3613         interpolation_stage=interpolation_stage,
#    3614         filternorm=filternorm,
#    3615         filterrad=filterrad,
#    3616         resample=resample,
#    3617         url=url,
#    3618         **({"data": data} if data is not None else {}),
#    3619         **kwargs,
#    3620     )
#    3621     sci(__ret)
#    3622     return __ret
#
# File ~/scripts/.venv/lib/python3.12/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File ~/scripts/.venv/lib/python3.12/site-packages/matplotlib/axes/_axes.py:5993, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5989 im.set_url(url)
#    5991 # update ax.dataLim, and, if autoscaling, set viewLim
#    5992 # to tightly fit the image, regardless of dataLim.
# -> 5993 im.set_extent(im.get_extent())
#    5995 self.add_image(im)
#    5996 return im
#
# File ~/scripts/.venv/lib/python3.12/site-packages/matplotlib/image.py:946, in AxesImage.set_extent(self, extent, **kwargs)
#     944 if kwargs:
#     945     raise _api.kwarg_error("set_extent", kwargs)
# --> 946 xmin = self.axes._validate_converted_limits(
#     947     xmin, self.convert_xunits)
#     948 xmax = self.axes._validate_converted_limits(
#     949     xmax, self.convert_xunits)
#     950 ymin = self.axes._validate_converted_limits(
#     951     ymin, self.convert_yunits)
#
# File ~/scripts/.venv/lib/python3.12/site-packages/matplotlib/axes/_base.py:3749, in _AxesBase._validate_converted_limits(self, limit, convert)
#    3746     converted_limit = converted_limit.squeeze()
#    3747 if (isinstance(converted_limit, Real)
#    3748         and not np.isfinite(converted_limit)):
# -> 3749     raise ValueError("Axis limits cannot be NaN or Inf")
#    3750 return converted_limit
#
# ValueError: Axis limits cannot be NaN or Inf

# %%
b1_new.shape
# Out:
# (911, 321)

# %%
plot_compB(x_new, y_new, b1_new, b2_new, b3_new, 3)

# %%
# Apply 2D FFT
b1_fft=np.fft.fft2(b1_new)
b2_fft=np.fft.fft2(b2_new)
b3_fft=np.fft.fft2(b3_new)

print(b3_fft.shape)
print_nan(b3_fft)
# Out:
# (800, 321)
# [[False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]
#  ...
#  [False False False ... False False False]
#  [False False False ... False False False]
#  [False False False ... False False False]]
# False
# There is  0 of NaNs out of an array of size: 256800
# (array([], dtype=int64), array([], dtype=int64))
# 0

# %%
# Shift the zero frequency component to the center
b1_fft=np.fft.fftshift(b1_fft)
b2_fft=np.fft.fftshift(b2_fft)
b3_fft=np.fft.fftshift(b3_fft)

# Compute the magnitude 
P_11_mag=np.abs(b1_fft)**2
P_22_mag=np.abs(b2_fft)**2
P_33_mag=np.abs(b3_fft)**2

# %%
fig, ax = plt.subplots()

im = ax.imshow(np.log10(P_11_mag).T,
               extent=[kxmin, kxmax, kymin, kymax],
               origin='lower',
            #    vmin=0,
            #    vmax=0.01,
               cmap='magma')

ax.set_title(r'$P_{11}(k_x,k_y)$', fontsize=fs)
ax.set_xlabel(r'$k_x$', fontsize=fs)
ax.set_ylabel(r'$k_y$', fontsize=fs)
ax.tick_params(axis='x', labelsize=fs)
ax.tick_params(axis='y', labelsize=fs)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

plt.colorbar(im, cax=cax).ax.tick_params(labelsize=fs)

# %%
fig, ax = plt.subplots()

im = ax.imshow(np.log10(P_22_mag).T,
               extent=[kxmin, kxmax, kymin, kymax],
               origin='lower',
               cmap='magma')

ax.set_title(r'$P_{22}(k_x,k_y)$', fontsize=fs)
ax.set_xlabel(r'$k_x$', fontsize=fs)
ax.set_ylabel(r'$k_y$', fontsize=fs)
ax.tick_params(axis='x', labelsize=fs)
ax.tick_params(axis='y', labelsize=fs)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

plt.colorbar(im, cax=cax).ax.tick_params(labelsize=fs)

# %%
fig, ax = plt.subplots()

im = ax.imshow(np.log10(P_33_mag).T,
               extent=[kxmin, kxmax, kymin, kymax],
               origin='lower',
               cmap='magma')

ax.set_title(r'$P_{33}(k_x,k_y)$', fontsize=fs)
ax.set_xlabel(r'$k_x$', fontsize=fs)
ax.set_ylabel(r'$k_y$', fontsize=fs)
ax.tick_params(axis='x', labelsize=fs)
ax.tick_params(axis='y', labelsize=fs)

from mpl_toolkits.axes_grid1 import make_axes_locatable
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.1)

plt.colorbar(im, cax=cax).ax.tick_params(labelsize=fs)

# %%
# try also to do an average over kx / ky to get 1D spectrum.
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], shape=(1001, 321))

# %%
# Boolean mask of NaN positions
mask = np.isnan(P_33_mag)
print(mask)
# [False  True False False]

# Check if there is at least one NaN
print(np.any(mask))
# True

# Count how many NaNs
print(np.sum(mask))
# 1

# Get indices of NaNs
print(np.where(mask))
# (array([1]),)
# Out:
# [[ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  ...
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]]
# True
# 321321
# (array([   0,    0,    0, ..., 1000, 1000, 1000], shape=(321321,)), array([  0,   1,   2, ..., 318, 319, 320], shape=(321321,)))
