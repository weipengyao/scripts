# %%
# %matplotlib qt
# Out:
# 2023-12-22 11:11:56.102 Python[25672:5293606] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.

# %%
import matplotlib as mpl
import happi
import numpy as np
import matplotlib.pyplot as plt

jetcmap = plt.cm.get_cmap("jet", 9) #generate a jet map with 10 values "rainbow", "jet", YlOrRd
jet_vals = jetcmap(np.arange(9)) #extract those values as an array 
jet_vals[0] = [1.0, 1, 1.0, 1] #change the first value 
jet_vals[8] = [0.0, 0, 0.0, 1] #change the first value 
newcmap = mpl.colors.LinearSegmentedColormap.from_list("mine", jet_vals)
# Out:
# /var/folders/2t/97rc3fl92tg15k2l_4sk5hsh0000gn/T/ipykernel_25672/616493249.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   jetcmap = plt.cm.get_cmap("jet", 9) #generate a jet map with 10 values "rainbow", "jet", YlOrRd

# %%
plt.rc('font', family='sans-serif', serif='Arial')
plt.rc('text', usetex=False)
plt.rc('xtick', labelsize=13)
plt.rc('ytick', labelsize=13)
plt.rc('axes', labelsize=13)
plt.rc('legend', fontsize=10)

# %%
import pandas as pd

# %%
data = pd.read_excel('/Users/yao/Desktop/VH_ave.xlsx')

# %%
ave = np.array(pd.DataFrame(data, columns=["ave"]))
ms1 = np.array(pd.DataFrame(data, columns=["measure 1"]))
ms2 = np.array(pd.DataFrame(data, columns=["measure 2"]))
ms3 = np.array(pd.DataFrame(data, columns=["measure 3"]))
str = np.array(pd.DataFrame(data, columns=["str_mat"]))

# %%
# read the theoretical deposited energy in each RCF layer

import scipy.io
in_layer = scipy.io.loadmat('/Users/yao/Desktop/inlayer.mat')
inlayer = np.array(in_layer['in_layer'])

# %%
inlayer.shape
# Out:
# (450, 20)

# %%
np.trapz(inlayer[:,1])
# Out:
# 43.42103468995119

# %%
yerr0=[np.abs(np.minimum(ave[:,0]-ms1[:,0], ave[:,0]-ms2[:,0], ave[:,0]-ms3[:,0]))/ave[0,0],
       np.maximum(ave[:,0]-ms1[:,0], ave[:,0]-ms2[:,0], ave[:,0]-ms3[:,0])/ave[0,0]
      ]

# %%
width  = 3.487 * 1.5
height = width / 1.618 

fig, ax = plt.subplots()
fig.subplots_adjust(left=.15, bottom=.16, right=.99, top=.97)

# experiment
ax.errorbar(np.linspace(1,14,14),
            ave[:,0]/ave[11,0],
            yerr=yerr0, 
            fmt='-k',markersize=8,
            mfc='none',
            ecolor='k',elinewidth=2.0,
            capsize=2.0, capthick = 2.0,
            label='Exp.'
           )


e_inc = np.linspace(1,45,450)
spectre = np.zeros_like(e_inc)
spectre_low  = np.zeros_like(e_inc)
spectre_high1 = np.zeros_like(e_inc)
spectre_high2 = np.zeros_like(e_inc)
for p in range (e_inc.size):
    spectre_low[p] = 20*np.exp(-1.*np.sqrt(2*e_inc[p]/0.5))
    # if e_inc[p] > 20:
    spectre_high1[p] = 0.1*np.exp(-0.5*((e_inc[p]-27.)/3.5)**4)
    # else:
    spectre_high2[p] = 0.03*np.exp(-0.5*((e_inc[p]-22.)/5)**4)
    spectre[p] =  spectre_low[p] + spectre_high1[p] + spectre_high2[p]

couche_low  = np.zeros_like(np.linspace(1,14,14))
couche_high1 = np.zeros_like(np.linspace(1,14,14))
couche_high2 = np.zeros_like(np.linspace(1,14,14))
couche      = np.zeros_like(np.linspace(1,14,14))
for f in range(14):
    couche_low[f]  = np.trapz(inlayer[:,f]*spectre_low[:])
    couche_high1[f] = np.trapz(inlayer[:,f]*spectre_high1[:])
    couche_high2[f] = np.trapz(inlayer[:,f]*spectre_high2[:])
    couche[f]      = np.trapz(inlayer[:,f]*spectre[:])
    
ax.plot(np.linspace(1,14,14), couche/couche[11], '-r', label='Sim. low+highs')
ax.plot(np.linspace(1,14,14), couche_low/couche[11],  '--b', label='Sim. low')
ax.plot(np.linspace(1,14,14), couche_high1/couche[11], ':c', label='Sim. high1')
ax.plot(np.linspace(1,14,14), couche_high2/couche[11], ':m', label='Sim. high2')

# ax.set_yscale('log')

ax.set_xlim([0,15])
ax.set_xticks([0,2,4,6,8,10,12,14])
ax.set_ylim([0,5])
ax.grid(linestyle='--',alpha=0.5)
ax.set_xlabel('No. of RCF')
ax.set_ylabel('Normalized dose')
ax.legend(fancybox=False, reverse=True, frameon=False)
fig.set_size_inches(width, height)
fig.tight_layout()

fig.savefig('/Users/yao/Desktop/Spec1.pdf',dpi=600)

fig, ax = plt.subplots()
fig.subplots_adjust(left=.15, bottom=.16, right=.99, top=.97)

ax.plot(e_inc, spectre, '-r', label='Spectrum low+highs')
ax.plot(e_inc, spectre_low,  '--b', label='Spectrum low')
ax.plot(e_inc, spectre_high1, ':c', label='Spectrum high1')
ax.plot(e_inc, spectre_high2, ':m', label='Spectrum high2')
ax.set_yscale('log')

ax.set_xlim([0,45])
ax.set_ylim([1e-5,1e2])
ax.grid(linestyle='--',alpha=0.5)
ax.set_xlabel('Energy (MeV)')
ax.set_ylabel('dN/dE')
ax.legend(fancybox=False, reverse=True, frameon=False)
fig.set_size_inches(width, height)
fig.tight_layout()
fig.savefig('/Users/yao/Desktop/Spec2.pdf',dpi=600)



# plt.show()

# %%
fig, ax = plt.subplots()
fig.subplots_adjust(left=.15, bottom=.16, right=.99, top=.97)

yerr0=[np.abs(np.minimum(ave[:,0]-ms1[:,0], ave[:,0]-ms2[:,0], ave[:,0]-ms3[:,0])),
       np.maximum(ave[:,0]-ms1[:,0], ave[:,0]-ms2[:,0], ave[:,0]-ms3[:,0])
      ]

ax.errorbar(np.linspace(1,14,14),
            ave[:,0],
            yerr=yerr0, 
            fmt='-k',markersize=8,
            mfc='none',
            ecolor='k',elinewidth=2.0,
            capsize=2.0, capthick = 2.0,
            label='Exp.'
           )

ax.plot(np.linspace(1,14,14), 500*couche, '-r', label='Sim.')



ax.set_xlim([0,15])
ax.set_xticks([0,2,4,6,8,10,12,14])
ax.set_ylim([0,3000])
ax.grid(linestyle='--',alpha=0.5)
ax.set_xlabel('No. of RCF')
ax.set_ylabel('Dose (Gy)')
ax.legend(fancybox=False, reverse=True, frameon=False)
fig.set_size_inches(width, height)
fig.tight_layout()

fig.savefig('/Users/yao/Desktop/Dose.pdf',dpi=600)

# %%
width  = 3.487 * 1.5
height = width / 1.618 

fig, ax = plt.subplots()
fig.subplots_adjust(left=.15, bottom=.16, right=.99, top=.97)

# experiment
ax.errorbar(np.linspace(1,14,14),
            ave[:,0],
            yerr=yerr0, 
            fmt='-k',markersize=8,
            mfc='none',
            ecolor='k',elinewidth=2.0,
            capsize=2.0, capthick = 2.0,
            label='Exp.'
           )

factor = 500

e_inc = np.linspace(1,45,450)
spectre = np.zeros_like(e_inc)
spectre_low  = np.zeros_like(e_inc)
spectre_high1 = np.zeros_like(e_inc)
spectre_high2 = np.zeros_like(e_inc)
for p in range (e_inc.size):
    spectre_low[p] = 20*np.exp(-1.*np.sqrt(2*e_inc[p]/0.5))*factor
    # if e_inc[p] > 20:
    spectre_high1[p] = 0.1*np.exp(-0.5*((e_inc[p]-27.)/3.5)**4)*factor
    # else:
    spectre_high2[p] = 0.03*np.exp(-0.5*((e_inc[p]-22.)/5)**4)*factor
    spectre[p] =  spectre_low[p] + spectre_high1[p] + spectre_high2[p]

couche_low  = np.zeros_like(np.linspace(1,14,14))
couche_high1 = np.zeros_like(np.linspace(1,14,14))
couche_high2 = np.zeros_like(np.linspace(1,14,14))
couche      = np.zeros_like(np.linspace(1,14,14))
for f in range(14):
    couche_low[f]  = np.trapz(inlayer[:,f]*spectre_low[:])
    couche_high1[f] = np.trapz(inlayer[:,f]*spectre_high1[:])
    couche_high2[f] = np.trapz(inlayer[:,f]*spectre_high2[:])
    couche[f]      = np.trapz(inlayer[:,f]*spectre[:])
    
ax.plot(np.linspace(1,14,14), couche, '-r', label='Sim. low+high')
ax.plot(np.linspace(1,14,14), couche_low,  '--b', label='Sim. low')
ax.plot(np.linspace(1,14,14), couche_high1, ':c', label='Sim. high1')
ax.plot(np.linspace(1,14,14), couche_high2, ':m', label='Sim. high2')

# ax.set_yscale('log')

ax.set_xlim([0,15])
ax.set_xticks([0,2,4,6,8,10,12,14])
ax.set_ylim([0,3000])
ax.grid(linestyle='--',alpha=0.5)
ax.set_xlabel('No. of RCF')
ax.set_ylabel('Dose (Gy)')
ax.legend(fancybox=False, reverse=True, frameon=False)
fig.set_size_inches(width, height)
fig.tight_layout()

fig.savefig('/Users/yao/Desktop/Dose2.pdf',dpi=600)

fig, ax = plt.subplots()
fig.subplots_adjust(left=.15, bottom=.16, right=.99, top=.97)

ax.plot(e_inc, spectre, '-r', label='Spectrum low+high')
ax.plot(e_inc, spectre_low,  '--b', label='Spectrum low')
ax.plot(e_inc, spectre_high1, ':c', label='Spectrum high1')
ax.plot(e_inc, spectre_high2, ':m', label='Spectrum high2')
ax.set_yscale('log')

ax.set_xlim([0,45])
ax.set_ylim([1e-2,1e4])
ax.grid(linestyle='--',alpha=0.5)
ax.set_xlabel('Energy (MeV)')
ax.set_ylabel(r'dN/dE/d$\Omega$')
ax.legend(fancybox=False, reverse=True, frameon=False)
fig.set_size_inches(width, height)
fig.tight_layout()

fig.savefig('/Users/yao/Desktop/Spec3.pdf',dpi=600)

# plt.show()

# %%
# calculate the deposited energy in each layer from the dose

surf_indiv = 7.168444444444446e-05
energy = ave*1.2e-3*surf_indiv*28e-4
doseAvg = energy / ((str/29.6)*1.2e-3* 28e-4)

# %%
spectre
# Out:
# array([1.35335283e+03, 1.22983429e+03, 1.12227462e+03, 1.02789644e+03,
#        9.44536642e+02, 8.70482360e+02, 8.04357756e+02, 7.45043891e+02,
#        6.91620776e+02, 6.43324648e+02, 5.99515945e+02, 5.59654946e+02,
#        5.23282976e+02, 4.90007753e+02, 4.59491817e+02, 4.31443325e+02,
#        4.05608637e+02, 3.81766322e+02, 3.59722251e+02, 3.39305566e+02,
#        3.20365345e+02, 3.02767819e+02, 2.86394049e+02, 2.71137961e+02,
#        2.56904691e+02, 2.43609176e+02, 2.31174945e+02, 2.19533094e+02,
#        2.08621397e+02, 1.98383534e+02, 1.88768434e+02, 1.79729690e+02,
#        1.71225061e+02, 1.63216027e+02, 1.55667403e+02, 1.48547000e+02,
#        1.41825324e+02, 1.35475309e+02, 1.29472085e+02, 1.23792766e+02,
#        1.18416266e+02, 1.13323134e+02, 1.08495402e+02, 1.03916457e+02,
#        9.95709163e+01, 9.54445271e+01, 9.15240654e+01, 8.77972504e+01,
#        8.42526666e+01, 8.08796924e+01, 7.76684358e+01, 7.46096764e+01,
#        7.16948122e+01, 6.89158113e+01, 6.62651683e+01, 6.37358644e+01,
#        4.83325365e-02, 4.75652794e-02, 4.68111789e-02, 4.60699915e-02,
#        4.53414783e-02, 4.46254056e-02, 4.39215440e-02, 4.32296688e-02,
#        4.25495597e-02, 4.18810009e-02, 4.12237807e-02, 4.05776916e-02,
#        3.99425304e-02, 3.93180976e-02, 3.87041978e-02, 3.81006394e-02,
#        3.75072345e-02, 3.69237991e-02, 3.63501524e-02, 3.57861175e-02,
#        3.52315208e-02, 3.46861921e-02, 3.41499644e-02, 3.36226740e-02,
#        3.31041605e-02, 3.25942664e-02, 3.20928373e-02, 3.15997219e-02,
#        3.11147718e-02, 3.06378411e-02, 3.01687873e-02, 2.97074700e-02,
#        2.92537520e-02, 2.88074985e-02, 2.83685772e-02, 2.79368584e-02,
#        2.75122149e-02, 2.70945219e-02, 2.66836570e-02, 2.62795000e-02,
#        2.58819332e-02, 2.54908407e-02, 2.51061093e-02, 2.47276276e-02,
#        2.43552864e-02, 2.39889785e-02, 2.36285988e-02, 2.32740441e-02,
#        2.29252131e-02, 2.25820066e-02, 2.22443269e-02, 2.19120784e-02,
#        2.15851672e-02, 2.12635010e-02, 2.09469896e-02, 2.06355440e-02,
#        2.03290771e-02, 2.00275034e-02, 1.97307389e-02, 1.94387013e-02,
#        1.91513096e-02, 1.88684845e-02, 1.85901480e-02, 1.83162235e-02,
#        1.80466360e-02, 1.77813117e-02, 1.75201782e-02, 1.72631644e-02,
#        1.70102005e-02, 1.67612181e-02, 1.65161498e-02, 1.62749296e-02,
#        1.60374926e-02, 1.58037752e-02, 1.55737147e-02, 1.53472498e-02,
#        1.51243203e-02, 1.49048667e-02])

# %%
inlayer.shape
# Out:
# (450, 20)

# %%
plt.errorbar(np.linspace(1,14,14), 
             ave[:,0]/ave[0,0], 
             yerr=[
                 np.abs(np.minimum(ave[:,0]-ms1[:,0], ave[:,0]-ms2[:,0], ave[:,0]-ms3[:,0]))/ave[0,0],
                 np.maximum(ave[:,0]-ms1[:,0], ave[:,0]-ms2[:,0], ave[:,0]-ms3[:,0])/ave[0,0]
             ],
             
            )
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
low  = np.minimum(ms1, ms2, ms3)

# %%
np.minimum(ave[:,0]-ms1[:,0], ave[:,0]-ms2[:,0], ave[:,0]-ms3[:,0])
# Out:
# array([-186.23744515,  -77.365929  , -114.73655506,  -42.2234008 ,
#         -23.50512548, -138.60547616,  -71.09474857,  -27.63012019,
#         -87.9669561 ,  -75.82240763, -130.98869403, -181.63762359,
#         -65.95378782,  -25.39352261])

# %%
np.maximum(ave[:,0]-ms1[:,0], ave[:,0]-ms2[:,0], ave[:,0]-ms3[:,0])
# Out:
# array([369.60180877,  92.33607411,  16.61178473,  49.72990619,
#         32.34563251, 282.56277812, 259.65144513,  10.72448624,
#         72.22100005, 105.37962636,  80.77528031, 159.89465705,
#         32.31268567,  45.42755249])

# %%
str/29.6
# Out:
# array([[0.00169805],
#        [0.00166092],
#        [0.00162501],
#        [0.00157801],
#        [0.00153302],
#        [0.00148993],
#        [0.00143799],
#        [0.00138872],
#        [0.00134194],
#        [0.00129748],
#        [0.0012552 ],
#        [0.00120678],
#        [0.0011611 ],
#        [0.00111797]])

# %%
ave
# Out:
# array([[2394.28463259],
#        [ 984.2862809 ],
#        [ 454.72419868],
#        [ 431.72447414],
#        [ 653.94814051],
#        [ 736.69173443],
#        [ 727.3221996 ],
#        [ 839.72821632],
#        [ 837.22632113],
#        [ 605.51620901],
#        [ 660.8480854 ],
#        [ 512.43371426],
#        [ 538.98209985],
#        [ 370.16078141]])
