# %%
from turtle import pos

import matplotlib

matplotlib.use("MacOSX")  # for mac users

# print(matplotlib.get_backend())

import sys

import matplotlib as mpl

sys.path.append("/Users/yao/Smilei")
import happi
import matplotlib.pyplot as plt
import numpy as np

jetcmap = plt.cm.get_cmap(
    "jet", 9
)  # generate a jet map with 10 values "rainbow", "jet", YlOrRd
jet_vals = jetcmap(np.arange(9))  # extract those values as an array
jet_vals[0] = [1.0, 1, 1.0, 1]  # change the first value
jet_vals[8] = [0.0, 0, 0.0, 1]  # change the first value
newcmap = mpl.colors.LinearSegmentedColormap.from_list("mine", jet_vals)

from matplotlib import font_manager

font_dirs = ["/Users/yao/Documents/Calibri and Cambria Fonts/"]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)

for font_file in font_files:
    font_manager.fontManager.addfont(font_file)

# set font
plt.rcParams["font.family"] = "Calibri"

plt.rc("text", usetex=False)
plt.rc("xtick", labelsize=14)
plt.rc("ytick", labelsize=14)
plt.rc("axes", labelsize=14)
plt.rc("legend", fontsize=12)

import scienceplots as splt

plt.style.use(["nature", "notebook", "grid", "high-vis"])
# Out:
# /var/folders/2t/97rc3fl92tg15k2l_4sk5hsh0000gn/T/ipykernel_61697/4159834250.py:18: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   jetcmap = plt.cm.get_cmap(

# %%
wkdir = [
    "/Users/yao/Smilei/tst1d_04_radiation_pressure_acc/",  # a0=300, ne=120nc, res=80
]

S0 = happi.Open(
    wkdir[0], reference_angular_frequency_SI=2.0 * np.pi * 3e8 / (1.0 * 1e-6)
)
# Out:
# Loaded simulation '/Users/yao/Smilei/tst1d_04_radiation_pressure_acc/'
# Scanning for Scalar diagnostics
# Scanning for Field diagnostics
# Scanning for Probe diagnostics
# Scanning for ParticleBinning diagnostics
# Scanning for RadiationSpectrum diagnostics
# Scanning for Performance diagnostics
# Scanning for Screen diagnostics
# Scanning for Tracked particle diagnostics
# Scanning for new particle diagnostics

# %%
ion_px = S0.ParticleBinning(0, sum={"x":"all"}, xmin=-10, xmax=200, 
                            # data_log=True,
                            # vmin=-5,
                            # vmax=0,
                            label='ion')
eon_px = S0.ParticleBinning(1, sum={"x":"all"}, xmin=-10, xmax=200, 
                            # data_log=True,
                            # vmin=-5,
                            # vmax=0,
                            label='eon')
eon_px.set(title='v0 = 0.1 c')
# Out:
# #1 - Number density of species # 1
#     x from 0 to 62.8319 in 200 steps
#     px from -10 to 300 in 200 steps
#
# average for all x
# The value in each bin is the sum of the `deposited_quantity` divided by the bin size

# %%
happi.multiSlide(ion_px, eon_px, 
                #  skipAnimation=True
                 )

# %%
ion_wm = S0.ParticleBinning(2, 
                            # sum={"x":"all"}, xmin=-10, xmax=200, 
                            # data_log=True,
                            # vmin=-5,
                            # vmax=0,
                            label='ion')#.slide()

eon_wm = S0.ParticleBinning(3, 
                            # sum={"x":"all"}, xmin=-10, xmax=200, 
                            # data_log=True,
                            # vmin=-5,
                            # vmax=0,
                            linestyle='--',
                            label='eon')#.slide()

happi.multiSlide(ion_wm, eon_wm)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
eon_wm = S0.ParticleBinning(3, 
                            # sum={"x":"all"}, xmin=-10, xmax=200, 
                            # data_log=True,
                            # vmin=-5,
                            # vmax=0,
                            label='eon').slide()
# Out:
# #3 - user_function of species # 1
#     x from 0 to 62.8319 in 200 steps
#
# The value in each bin is the sum of the `deposited_quantity` divided by the bin size

# %%
eon_t = S0.TrackParticles('eon',axes=["px"],label='eon')
ion_t = S0.TrackParticles('ion',axes=["px"],label='ion')
# Out:
# Ordering particles ... (this could take a while)
# Number of particles: 5000
#     Ordering @ timestep = 0
#     Ordering @ timestep = 1
#     Ordering @ timestep = 2
#     Ordering @ timestep = 3
#     Ordering @ timestep = 4
#     Ordering @ timestep = 5
#     Ordering @ timestep = 6
#     Ordering @ timestep = 7
#     Ordering @ timestep = 8
#     Ordering @ timestep = 9
#     Ordering @ timestep = 10
#     Ordering @ timestep = 11
#     Ordering @ timestep = 12
#     Ordering @ timestep = 13
#     Ordering @ timestep = 14
#     Ordering @ timestep = 15
#     Ordering @ timestep = 16
#     Ordering @ timestep = 17
#     Ordering @ timestep = 18
#     Ordering @ timestep = 19
#     Ordering @ timestep = 20
#     Ordering @ timestep = 21
#     Ordering @ timestep = 22
#     Ordering @ timestep = 23
#     Ordering @ timestep = 24
#     Ordering @ timestep = 25
#     Ordering @ timestep = 26
#     Ordering @ timestep = 27
#     Ordering @ timestep = 28
#     Ordering @ timestep = 29
# ...

# %%
eon_t.set(yscale='log')
ion_t.set(yscale='log')
ion_t.set(vmin=0.01, vmax=300, xmin=0, xmax=1)
happi.multiPlot(eon_t, ion_t, skipAnimation=True)
# Out:
# Loading data ...
#    axis: px
# Process broken lines ...
# ... done
# Loading data ...
#    axis: px
# Process broken lines ...
# ... done
# /Users/yao/Smilei/happi/_Utils.py:669: UserWarning: Legend does not support handles for list instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/users/explain/axes/legend_guide.html#controlling-the-legend-entries
#   self.ax[0].legend(
