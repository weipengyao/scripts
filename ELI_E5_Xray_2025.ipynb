# %%
# %matplotlib qt

# %%
import matplotlib as mpl
import sys
sys.path.append("/Users/yao/Smilei")
import happi
import numpy as np
import matplotlib.pyplot as plt

jetcmap = plt.cm.get_cmap("jet", 9) #generate a jet map with 10 values "rainbow", "jet", YlOrRd
jet_vals = jetcmap(np.arange(9)) #extract those values as an array 
jet_vals[0] = [1.0, 1, 1.0, 1] #change the first value 
jet_vals[8] = [0.0, 0, 0.0, 1] #change the first value 
newcmap = mpl.colors.LinearSegmentedColormap.from_list("mine", jet_vals) 

from matplotlib import font_manager

font_dirs = ['/Users/yao/Documents/Calibri and Cambria Fonts/']
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)

for font_file in font_files:
    font_manager.fontManager.addfont(font_file)

# set font
plt.rcParams['font.family'] = 'Calibri'

plt.rc('text', usetex=False)
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)
plt.rc('axes', labelsize=14)
plt.rc('legend', fontsize=12)
# Out:
# /var/folders/2t/97rc3fl92tg15k2l_4sk5hsh0000gn/T/ipykernel_69598/621321092.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   jetcmap = plt.cm.get_cmap("jet", 9) #generate a jet map with 10 values "rainbow", "jet", YlOrRd

# %% [markdown]
# ## Preliminary analysis of the electron spectra measurements

# %%
import pandas as pd

# Load the data of the electron spectra from CSV files
shot29 = "/Users/yao/Desktop/shot29.csv"  # Update this path if necessary
df_29 = pd.read_csv(shot29)

shot30 = "/Users/yao/Desktop/shot30.csv"  # Update this path if necessary
df_30 = pd.read_csv(shot30)

shot31 = "/Users/yao/Desktop/shot31.csv"  # Update this path if necessary
df_31 = pd.read_csv(shot31)

shot32 = "/Users/yao/Desktop/shot32.csv"  # Update this path if necessary
df_32 = pd.read_csv(shot32)

shot33 = "/Users/yao/Desktop/shot33.csv"  # Update this path if necessary
df_33 = pd.read_csv(shot33)

shot34 = "/Users/yao/Desktop/shot34.csv"  # Update this path if necessary
df_34 = pd.read_csv(shot34)

shot35 = "/Users/yao/Desktop/shot35.csv"  # Update this path if necessary
df_35 = pd.read_csv(shot35)


shot37 = "/Users/yao/Desktop/shot37.csv"  # Update this path if necessary
df_37 = pd.read_csv(shot37)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       3 # Load the data of the electron spectra from CSV files
#       4 shot29 = "/Users/yao/Desktop/shot29.csv"  # Update this path if necessary
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Set font to Calibri and increase font sizes
plt.rcParams.update({
    'font.family': 'Calibri',
    'font.size': 24,
    'axes.titlesize': 28,
    'axes.labelsize': 24,
    'legend.fontsize': 20,
    'xtick.labelsize': 24,
    'ytick.labelsize': 24
})

# Create the plot
plt.figure(figsize=(12, 8))
plt.plot(df_29["Distance_(cm)"], df_29["Gray_Value"], linestyle='-', label="shot 29")
plt.plot(df_30["Distance_(cm)"], df_30["Gray_Value"], linestyle='-', label="shot 30")
plt.plot(df_31["Distance_(cm)"], df_31["Gray_Value"], linestyle='-', label="shot 31")
plt.plot(df_32["Distance_(cm)"], df_32["Gray_Value"], linestyle='-', label="shot 32")
plt.plot(df_33["Distance_(cm)"], df_33["Gray_Value"], linestyle='-', label="shot 33")
plt.plot(df_34["Distance_(cm)"], df_34["Gray_Value"], linestyle='-', label="shot 34")
plt.plot(df_35["Distance_(cm)"], df_35["Gray_Value"], linestyle='-', label="shot 35")
plt.plot(df_37["Distance_(cm)"], df_37["Gray_Value"], linestyle='-', label="shot 37")
plt.title("Gray Value vs Distance")
plt.xlabel("Distance (cm)")
plt.ylabel("Gray Value")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.yscale('log')
plt.xlim(0, 14)
plt.ylim(1e2, 1e5)
plt.show()

# %% [markdown]
# ## load electron spectra data

# %%
# shot 105, 30 nm SiN
ene105 = np.loadtxt('/Users/yao/Nextcloud/PROJECTS/ELI/Xray-April2025/e_spectra/ene105.txt') # 30 nm SiN
num105 = np.loadtxt('/Users/yao/Nextcloud/PROJECTS/ELI/Xray-April2025/e_spectra/num105.txt')

# shot 102, 150 nm SiN
ene102 = np.loadtxt('/Users/yao/Nextcloud/PROJECTS/ELI/Xray-April2025/e_spectra/ene102.txt') # 150 nm SiN
num102 = np.loadtxt('/Users/yao/Nextcloud/PROJECTS/ELI/Xray-April2025/e_spectra/num102.txt')

# shot80-81, 2 um Au
ene8081 = np.loadtxt('/Users/yao/Nextcloud/PROJECTS/ELI/Xray-April2025/e_spectra/ene8081.txt') # 2 um Au
num8081 = np.loadtxt('/Users/yao/Nextcloud/PROJECTS/ELI/Xray-April2025/e_spectra/num8081.txt')

# shot78-79, 3 um Au
ene7879 = np.loadtxt('/Users/yao/Nextcloud/PROJECTS/ELI/Xray-April2025/e_spectra/ene7879.txt') # 3 um Au
num7879 = np.loadtxt('/Users/yao/Nextcloud/PROJECTS/ELI/Xray-April2025/e_spectra/num7879.txt')

# shot72-73, 10 um Au
ene7273 = np.loadtxt('/Users/yao/Nextcloud/PROJECTS/ELI/Xray-April2025/e_spectra/ene7273.txt') # 10 um Au
num7273 = np.loadtxt('/Users/yao/Nextcloud/PROJECTS/ELI/Xray-April2025/e_spectra/num7273.txt')

# shot 74-75, 25 um W
ene7475 = np.loadtxt('/Users/yao/Nextcloud/PROJECTS/ELI/Xray-April2025/e_spectra/ene7475.txt') # 25 um W
num7475 = np.loadtxt('/Users/yao/Nextcloud/PROJECTS/ELI/Xray-April2025/e_spectra/num7475.txt')

# shot 76-77, 50 um Au
ene7677 = np.loadtxt('/Users/yao/Nextcloud/PROJECTS/ELI/Xray-April2025/e_spectra/ene7677.txt') # 50 um Au
num7677 = np.loadtxt('/Users/yao/Nextcloud/PROJECTS/ELI/Xray-April2025/e_spectra/num7677.txt')

# %%
# Set font to Calibri and increase font sizes
plt.rcParams.update({
    'font.family': 'Calibri',
    'font.size': 24,
    'axes.titlesize': 28,
    'axes.labelsize': 24,
    'legend.fontsize': 16,
    'xtick.labelsize': 24,
    'ytick.labelsize': 24
})

# Create the plot
plt.figure(figsize=(8, 6))
plt.plot(ene105, num105, linestyle='-', color='red', label="#105, 30 nm")
plt.plot(ene102, num102, linestyle='-', color='blue', label="#102, 150 nm")
plt.plot(ene8081, num8081, linestyle='-', color='green', label="#80-81, 2 um Au")
plt.plot(ene7879, num7879, linestyle='-', color='orange', label="#78-79, 3 um Au")
plt.plot(ene7273, num7273, linestyle='-', color='purple', label="#72-73, 10 um Au")
plt.plot(ene7475, num7475, linestyle='-', color='brown', label="#74-75, 25 um W")
plt.plot(ene7677, num7677, linestyle='-', color='black', label="#76-77, 50 um Au")
# plt.title("Gray Value vs Distance")
plt.xlabel("Energy (MeV)")
plt.ylabel("dN/dE (a.u.)")
plt.legend()
# plt.grid(True)
plt.yscale('log')
plt.tight_layout()

plt.xlim(0, 60)
plt.ylim(1e8, 2e11)
plt.show()

# %% [markdown]
# ## target thickness vs. proton cutoff energy measurements

# %%
# old intepretation
# thickness and cutoff energy

thickness_SiN     = np.array([30.0, 100.0, 150.0, 300.0])
cutoff_energy_SiN = np.array([ 3.2,   3.2,   5.7,   4.6])

thickness_Al      = np.array([2000.0, 3000.0, 20000.0, 50000.0, 100000.0])
cutoff_energy_Al  = np.array([  27.6,   18.7,    16.8,     5.7,      1.1])

thickness_Au      = np.array([2000.0, 10000.0, 25000, 50000.0, 125000.0])
cutoff_energy_Au  = np.array([   5.7,     4.6,   1.1,     1.1,       1.1])

# %%
# new intepretation
# thickness and cutoff energy

thickness_SiN     = np.array([30.0, 100.0, 150.0, 200.0, 300.0, 2000.0])
cutoff_energy_SiN = np.array([23.2,   3.2, 27.55, 18.65,  9.66,   5.67])

thickness_Al      = np.array([2000.0, 3000.0, 20000.0, 50000.0, 50000.0, 100000.0, 150000.0])
cutoff_energy_Al  = np.array([ 27.55,  18.65,   16.75,   16.75,     7.5,     5.67,     5.67])

thickness_Au      = np.array([2000.0, 10000.0, 25000, 50000.0, 125000.0])
cutoff_energy_Au  = np.array([ 18.65,   18.65,   7.5,    9.66,      1.1])

# %%
# more data on 28/04/2025
# thickness and cutoff energy

thickness_SiN     = np.array([30.0, 100.0, 150.0, 200.0, 300.0, 500.0, 2000.0])
cutoff_energy_SiN = np.array([23.2,   3.2, 27.55, 18.65,  9.66,  17.6, 5.67])

thickness_Al      = np.array([800.0, 1500.0, 2000.0, 3000.0, 20000.0, 50000.0, 50000.0, 100000.0, 150000.0])
cutoff_energy_Al  = np.array([ 17.6,   20.0,  27.55,  18.65,   16.75,   16.75,     7.5,     5.67,     5.67])

thickness_Au      = np.array([2000.0, 10000.0, 25000, 25000, 50000.0, 125000.0])
cutoff_energy_Au  = np.array([ 18.65,   18.65,  20.0,   7.5,    9.66,      1.1])

# %%
# get rid of the clearly missed target data on 04/05/2025
# thickness and cutoff energy

thickness_SiN     = np.array([30.0, 150.0, 200.0, 500.0])
cutoff_energy_SiN = np.array([23.2, 27.55, 18.65,  17.6])

thickness_Al      = np.array([800.0, 1500.0, 2000.0, 3000.0, 20000.0, 50000.0, 100000.0, 150000.0])
cutoff_energy_Al  = np.array([ 17.6,   20.0,  27.55,  18.65,   16.75,   16.75,     5.67,     5.67])

thickness_Au      = np.array([2000.0, 10000.0, 25000, 50000.0, 125000.0])
cutoff_energy_Au  = np.array([ 18.65,   18.65,  20.0,    9.66,      1.1])

# %%
# plot each material's data separately for clearity 01/07/2025
# update the maximum energy data by rechecking the RCF layers
# thickness and cutoff energy

thickness_SiN     = np.array([30.0, 150.0, 200.0, 500.0])
cutoff_energy_SiN = np.array([23.2, 23.2, 18.65,  17.6])

thickness_Al      = np.array([800.0, 1500.0, 2000.0, 3000.0, 20000.0, 50000.0, 100000.0, 150000.0])
cutoff_energy_Al  = np.array([ 17.6,   20.0,  27.55,  18.65,   16.75,   16.75,     5.67,     5.67])

thickness_Au      = np.array([2000.0, 10000.0, 25000, 50000.0, 125000.0])
cutoff_energy_Au  = np.array([ 18.65,   18.65,  22.2,    9.66,      1.1])

# %%
# plot each material's data separately for clearity 02/07/2025
# update the maximum energy data by rechecking the RCF layers one-by-one
# thickness and cutoff energy

thickness_SiN     = np.array([30.0, 150.0, 300.0, 500.0])
cutoff_energy_SiN = np.array([23.2, 23.2,  18.65,  17.6])

thickness_Al      = np.array([800., 2000., 3000., 20000., 50000.,])
cutoff_energy_Al  = np.array([17.6, 31.4,  18.65, 16.75,  16.75,])

thickness_Au      = np.array([2000.0, 10000.0, 25000, 50000.0, 125000.0])
cutoff_energy_Au  = np.array([ 18.65,   18.65,  22.2,     1.1,      1.1])

# %%
# plot each material's data separately for clearity 03/07/2025
# update the maximum energy data by rechecking the RCF layers one-by-one
# thickness and cutoff energy

thickness_SiN     = np.array([30.0, 150.0, 300.0, 500.0])
cutoff_energy_SiN = np.array([23.2, 23.2,  18.65,  17.6])

thickness_Al      = np.array([800., 2000., 3000., 20000., 50000.,])
cutoff_energy_Al  = np.array([17.6, 27.55,  18.65, 16.75,  16.75,])

thickness_Au      = np.array([2000.0, 10000.0, 25000, 50000.0, 125000.0])
cutoff_energy_Au  = np.array([ 18.65,   18.65,  22.2,     1.1,      1.1])

# %%
# plot each material's data separately for clearity 07/07/2025
# update the maximum energy data by rechecking the RCF layers one-by-one
# thickness and cutoff energy

thickness_SiN     = np.array([30.0, 150.0, 200.0, 500.0])
cutoff_energy_SiN = np.array([23.2, 23.2,  16.75,  17.6])
err_SiN           = np.array([4.35, 4.35,    1.9,   2.4])  # Adding error values for SiN
# Create (2, N) array for asymmetric error bars
yerr_SiN = np.vstack((np.zeros_like(err_SiN), err_SiN))

thickness_Al      = np.array([800., 1500., 2000., 3000., 20000., 50000.,])
cutoff_energy_Al  = np.array([17.6, 22.2,   31.4, 18.65, 16.75,  16.75,])
err_Al            = np.array([ 2.4,  2.1,    3.6,  4.55,   1.9,    1.9,])  # Adding error values for Al
# Create (2, N) array for asymmetric error bars
yerr_Al = np.vstack((np.zeros_like(err_Al), err_Al))

thickness_Au      = np.array([2000.0, 10000.0, 25000, 50000.0, 125000.0])
cutoff_energy_Au  = np.array([ 18.65,   18.65,  22.2,     1.1,      1.1])
err_Au            = np.array([  4.55,    4.55,   2.1,     2.1,      2.1])  # Adding error values for Au
# Create (2, N) array for asymmetric error bars
yerr_Au = np.vstack((np.zeros_like(err_Au), err_Au))

# %%
thickness_all = np.concatenate((thickness_SiN, thickness_Al, thickness_Au))
cutoff_energy_all = np.concatenate((cutoff_energy_SiN, cutoff_energy_Al, cutoff_energy_Au))

# %%
# Sort thickness_all and reorder cutoff_energy_all accordingly
sorted_indices = np.argsort(thickness_all)
thickness_all_sorted = thickness_all[sorted_indices]
cutoff_energy_all_sorted = cutoff_energy_all[sorted_indices]

# Verify the results
thickness_all_sorted, cutoff_energy_all_sorted

# %%
# Remove the 8th element (index 7) from both arrays
thickness_all_sorted = np.delete(thickness_all_sorted, 7)
thickness_all_sorted = np.delete(thickness_all_sorted, -2)
cutoff_energy_all_sorted = np.delete(cutoff_energy_all_sorted, 7)
cutoff_energy_all_sorted = np.delete(cutoff_energy_all_sorted, -2)

# Verify the results
thickness_all_sorted, cutoff_energy_all_sorted

# %%
# Set font to Calibri and increase font sizes
plt.rcParams.update({
    'font.family': 'Calibri',
    'font.size': 24,
    'axes.titlesize': 28,
    'axes.labelsize': 24,
    'legend.fontsize': 20,
    'xtick.labelsize': 24,
    'ytick.labelsize': 24
})

# Create the plot
plt.figure(figsize=(12, 8))
plt.plot(thickness_SiN, cutoff_energy_SiN, marker='o', label="SiN")
plt.plot(thickness_Al,  cutoff_energy_Al,  marker='*', linestyle='--', label="Al")
plt.plot(thickness_Au,  cutoff_energy_Au,  marker='s', linestyle=':', label="Au & W")
plt.title("thickness vs cutoff energy")
plt.xlabel("Thickness (nm)")
plt.ylabel("Cutoff Energy (MeV)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.xscale('log')
plt.xlim(10, 200000)
plt.ylim(0, 30)
plt.grid(True, which='both', linestyle='-', linewidth=0.5, alpha=0.5)
plt.show()

# %%
# Set font to Calibri and increase font sizes
plt.rcParams.update({
    'font.family': 'Calibri',
    'font.size': 24,
    'axes.titlesize': 28,
    'axes.labelsize': 24,
    'legend.fontsize': 20,
    'xtick.labelsize': 24,
    'ytick.labelsize': 24
})

# Create the plot
plt.figure(figsize=(8, 5))
plt.plot(thickness_all_sorted[0:4]*1e-3, cutoff_energy_all_sorted[0:4], 
         marker='o', linestyle='--',
         linewidth=2, markersize=8, color='blue', label="SiN")
# plt.plot(thickness_all_sorted*1e-3, cutoff_energy_all_sorted, 
#          marker='o', linestyle='--',
#          linewidth=2, markersize=8, color='blue')
# plt.title("thickness vs cutoff energy")
plt.xlabel("Thickness (um)")
plt.ylabel("Cutoff Energy (MeV)")
# plt.legend()
plt.grid(True)
plt.tight_layout()
plt.xscale('log')
plt.xlim(0.01, 1000)
plt.ylim(0, 30)
plt.grid(True, which='both', linestyle='-', linewidth=0.5, alpha=0.5)
plt.show()
# plt.savefig("/Users/yao/Desktop/thickness_vs_cutoff_energy.pdf", dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 14
#      12 # Create the plot
#      13 plt.figure(figsize=(8, 5))
# ---> 14 plt.plot(thickness_all_sorted[0:4]*1e-3, cutoff_energy_all_sorted[0:4],
#      15          marker='o', linestyle='--',
#      16          linewidth=2, markersize=8, color='blue', label="SiN")
#      17 # plt.plot(thickness_all_sorted*1e-3, cutoff_energy_all_sorted,
#      18 #          marker='o', linestyle='--',
#      19 #          linewidth=2, markersize=8, color='blue')
#      20 # plt.title("thickness vs cutoff energy")
#      21 plt.xlabel("Thickness (um)")
#
# NameError: name 'thickness_all_sorted' is not defined

# %%
# Set font to Calibri and increase font sizes
plt.rcParams.update({
    'font.family': 'Calibri',
    'font.size': 24,
    'axes.titlesize': 28,
    'axes.labelsize': 24,
    'legend.fontsize': 20,
    'xtick.labelsize': 24,
    'ytick.labelsize': 24
})

# Create the plot
plt.figure(figsize=(8, 5))
plt.plot(thickness_SiN*1e-3, cutoff_energy_SiN, 
         marker='o', linestyle='-',
         linewidth=2, markersize=8, color='red', label="SiN")
plt.plot(thickness_Al*1e-3, cutoff_energy_Al, 
         marker='s', linestyle='--',
         linewidth=2, markersize=8, color='k', label="Al")
plt.plot(thickness_Au*1e-3, cutoff_energy_Au, 
         marker='^', linestyle='-.',
         linewidth=2, markersize=8, color='blue', label="Au & W")

plt.xlabel("Thickness (um)")
plt.ylabel("Cutoff Energy (MeV)")
plt.legend(loc='lower left')
plt.tight_layout()
plt.xscale('log')
plt.xlim(0.02, 200)
plt.ylim(0, 32)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.5)
# plt.show()
# plt.savefig("/Users/yao/Desktop/thickness_vs_cutoff_energy.pdf", dpi=600, bbox_inches='tight')

# %%
# Set font to Calibri and increase font sizes
plt.rcParams.update({
    'font.family': 'Calibri',
    'font.size': 24,
    'axes.titlesize': 28,
    'axes.labelsize': 24,
    'legend.fontsize': 16,
    'xtick.labelsize': 24,
    'ytick.labelsize': 24
})

# Create the plot
plt.figure(figsize=(8, 5))
plt.errorbar(thickness_SiN*1e-3, cutoff_energy_SiN, yerr=yerr_SiN,
             capsize=3,capthick=2,
         marker='o', linestyle=':',
         linewidth=1, markersize=8, color='red', label="SiN")

# Add arrowheads manually
for x, y, err in zip(thickness_SiN*1e-3, cutoff_energy_SiN, err_SiN):
    plt.annotate(
        '', xy=(x, y + err), xytext=(x, y),
        arrowprops=dict(arrowstyle='<-', color='red', lw=2,  mutation_scale=16)
    )

plt.errorbar(thickness_Al*1e-3, cutoff_energy_Al, yerr=yerr_Al,
            capsize=3,capthick=2, 
         marker='s', linestyle=':',
         linewidth=1, markersize=8, color='k', label="Al")

# Add arrowheads manually
for x, y, err in zip(thickness_Al*1e-3, cutoff_energy_Al, err_Al):
    plt.annotate(
        '', xy=(x, y + err), xytext=(x, y),
        arrowprops=dict(arrowstyle='<-', color='k', lw=2,  mutation_scale=16)
    )


plt.errorbar(thickness_Au*1e-3, cutoff_energy_Au, yerr=yerr_Au,
         capsize=3,capthick=2,
         marker='*', linestyle=':',
         linewidth=1, markersize=12, color='blue', label="Au & W")

# Add arrowheads manually
for x, y, err in zip(thickness_Au*1e-3, cutoff_energy_Au, err_Au):
    plt.annotate(
        '', xy=(x, y + err), xytext=(x, y),
        arrowprops=dict(arrowstyle='<-', color='blue', lw=2, mutation_scale=16)
    )

plt.xlabel("Thickness (um)")
plt.ylabel("Cutoff Energy (MeV)")
plt.legend(loc='lower left')
plt.tight_layout()
plt.xscale('log')
plt.xlim(0.02, 200)
plt.ylim(0, 40)
# plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.5)
plt.show()
# plt.savefig("/Users/yao/Desktop/thickness_vs_cutoff_energy.pdf", dpi=600, bbox_inches='tight')

# %%
cutoff_energy_all_sorted

# %% [markdown]
# ## proton energy spectra
#
# #### together with the Apollon F2 and PIC simulations

# %%
# proton energy spectra

# load apollon data
## w/o DPM - 1.5 um Al
#shot 193
exp_energy_193  = np.array([4.71,    7.76,   10.01,  12.64,  14.78,  16.70,  18.97,  20.89,  22.55,  24.00,  25.25]) 
exp_number_193  = np.array([6.79e9, 4.92e9, 2.51e9, 1.39e9, 4.73e8, 3.53e8, 9.26e7, 5.53e7, 4.00e7, 2.91e7, 2.15e7]) 

#shot 194
exp_energy_194  = np.array([4.83,    7.90,   10.16,  12.79,  14.92,  16.82,  19.07,  20.95,  22.58,  24.01,  25.25]) 
exp_number_194  = np.array([5.78e9, 4.54e9, 1.63e9, 9.77e8, 6.50e8, 4.35e8, 2.09e8, 7.92e7, 5.43e7, 4.37e7, 3.35e7]) 

exp_energy_nodpm = np.mean(np.stack((exp_energy_193, exp_energy_194)), axis=0)
exp_energy_nodpm_xerr_min = np.stack((exp_energy_193, exp_energy_194)).min(axis=0)
exp_energy_nodpm_xerr_max = np.stack((exp_energy_193, exp_energy_194)).max(axis=0)
exp_energy_nodpm_xerr = np.stack((np.abs(exp_energy_nodpm_xerr_min - exp_energy_nodpm), 
                                  np.abs(exp_energy_nodpm_xerr_max - exp_energy_nodpm))
                                ).min(axis=0)

exp_number_nodpm = np.mean(np.stack((exp_number_193, exp_number_194)), axis=0)
exp_number_nodpm_yerr_min = np.stack((exp_number_193, exp_number_194)).min(axis=0)
exp_number_nodpm_yerr_max = np.stack((exp_number_193, exp_number_194)).max(axis=0)
exp_number_nodpm_yerr = np.stack((np.abs(exp_number_nodpm_yerr_min - exp_number_nodpm), 
                                  np.abs(exp_number_nodpm_yerr_max - exp_number_nodpm))
                                ).min(axis=0)

## with DPM - 200 nm Si + 50 nm Al
# #shot 115
# exp_energy_115 = np.array([4.47, 7.42, 9.55, 11.92, 13.71, 15.12])
# exp_number_115 = np.array([2.263e9, 1.185e9, 5.523e8, 1.790e8, 5.399e7, 3.149e7])

#shot 56
exp_energy_56  = np.array([4.9,         8.0,    10.3,    13.0,    15.1,    17.1,    19.5,    21.5,    23.4,    25.0,    26.5,    28.1,    29.5,   30.9,   33.67,   35.17]) 
exp_number_56  = np.array([2.71e9,   2.29e9,  1.30e9,  8.10e8,  6.20e8,  2.78e8,  2.53e8,  1.10e8,  7.93e7,  5.87e7,  3.91e7,  1.96e7,  1.25e7, 1.01e7, 5.565e6, 5.165e6]) 

#shot 111
exp_energy_111 = np.array([4.49,       7.74,   10.01,   12.67,   14.87,   16.88,   19.33,   21.47,   23.42,   25.23,   26.90,   28.75,   30.37,   32.03,   33.67,   35.17])
exp_number_111 = np.array([4.333e9, 4.103e9, 2.892e9, 1.386e9, 1.074e9, 4.606e8, 2.639e8, 1.605e8, 9.902e7, 7.454e7, 4.993e7, 2.849e7, 2.184e7, 1.170e7, 5.565e6, 5.165e6])

#shot 112
exp_energy_112 = np.array([4.76,       7.83,   10.10,   12.76,   14.95,   16.94,   19.34,   21.41,   23.26,   24.95,   26.48,   28.14,   29.57,   30.95,   33.67,   35.17])
exp_number_112 = np.array([3.252e9, 2.844e9, 1.888e9, 1.286e9, 8.366e8, 3.199e8, 2.005e8, 1.081e8, 6.068e7, 3.840e7, 3.108e7, 1.871e7, 1.021e7, 1.428e7, 5.565e6, 5.165e6])

# #shot 216
# exp_energy_216  = np.array([4.54,      7.53,    9.73,   12.27,    14.3,   16.05,   17.99,   19.48,]) 
# exp_number_216  = np.array([2.25e9,  1.36e9,  7.65e8,  2.76e8,  1.01e8,  5.01e7,  1.74e7,  1.20e7,]) 

exp_energy_dpm_data     = np.stack((exp_energy_56, exp_energy_111, exp_energy_112))
exp_energy_dpm          = np.mean(exp_energy_dpm_data, axis=0)
exp_energy_dpm_xerr_min = exp_energy_dpm_data.min(axis=0)
exp_energy_dpm_xerr_max = exp_energy_dpm_data.max(axis=0)
exp_energy_dpm_xerr     = np.stack((np.abs(exp_energy_dpm_xerr_min - exp_energy_dpm), 
                                    np.abs(exp_energy_dpm_xerr_max - exp_energy_dpm))
                                  ).min(axis=0)

exp_number_dpm_data     = np.stack((exp_number_56, exp_number_111, exp_number_112))
exp_number_dpm          = np.mean(exp_number_dpm_data, axis=0)
exp_number_dpm_yerr_min = exp_number_dpm_data.min(axis=0)
exp_number_dpm_yerr_max = exp_number_dpm_data.max(axis=0)
exp_number_dpm_yerr     = np.stack((np.abs(exp_number_dpm_yerr_min - exp_number_dpm), 
                                    np.abs(exp_number_dpm_yerr_max - exp_number_dpm))
                                  ).min(axis=0)

# %%
# load ELI new data

filedir = "/Users/yao/Nextcloud/PROJECTS/ELI/Xray-April2025/proton_spectra/"

shot20 = np.loadtxt(filedir+"shot20_10um_Au/DN_DE_20.txt")      # Update this path if necessary
shot16 = np.loadtxt(filedir+"shot16_30nm_SiN/DN_DE_16.txt")  # Update this path if necessary
shot17 = np.loadtxt(filedir+"shot17_150nm_SiN/DN_DE_17.txt")  # Update this path if necessary
shot43 = np.loadtxt(filedir+"shot43_500nm_SiN/DN_DE_43.txt")      # Update this path if necessary

# %%
# get rid of the clearly missed RCF layer data on 04/05/2025
shot16 = np.delete(shot16, 7, axis=0)
shot20 = np.delete(shot20, 7, axis=0)

# %%
width  = 3.487 * 2
height = width / 1.618 * 1.2

fig, ax = plt.subplots()
fig.subplots_adjust(left=.15, bottom=.16, right=.99, top=.97)

# experiment
ax.plot(exp_energy_nodpm, exp_number_nodpm,
        linestyle=':', linewidth=1,
        # marker='s', markersize=8, 
        color='orange',
        label='Apollon 1.5 um Al')

ax.plot(exp_energy_dpm, exp_number_dpm,
        linestyle=':', linewidth=1,
        # marker='s', markersize=8, 
        color='green',
        label='Apollon 200 nm SiN')

# ax.errorbar(exp_energy_nodpm, exp_number_nodpm, 
#             yerr=exp_number_nodpm_yerr, 
#             xerr=exp_energy_nodpm_xerr,
#             fmt='.b',markersize=6,
#             mfc='none',
#             ecolor='b',elinewidth=1.0,
#             capsize=2.0, capthick = 1.0,
#             label='Apollon 1.5 um Al' 
#            )
ax.set_yscale('log')


# ax.errorbar(exp_energy_dpm, exp_number_dpm, 
#             yerr=exp_number_dpm_yerr, 
#             xerr=exp_energy_dpm_xerr,
#             fmt='.r',markersize=4,
#             mfc='none',mew=1.0,
#             ecolor='r',elinewidth=1.0,
#             capsize=2.0, capthick = 1.0,
#             label='Apollon 200 nm SiN'
#            )

ax.plot(shot16[:,1], shot16[:,0],
        linestyle='-', marker='o', markersize=8, color='red',
        linewidth=2,
        label='ELI 30 nm SiN')


ax.plot(shot20[:,1], shot20[:,0],
        linestyle='--', marker='s', markersize=8, color='blue',
        linewidth=2,
        label='ELI 10 um Au')




ax.set_xlim([0,40])
ax.set_ylim([1e6,1e12])
# ax.grid(linestyle='--',alpha=0.5)
ax.set_xlabel('Energy (MeV)')
ax.set_ylabel('dN/dE (No./MeV)')
ax.legend(fancybox=False, reverse=True, frameon=False)
fig.set_size_inches(width, height)
fig.tight_layout()

# plt.show()

# plt.savefig("/Users/yao/Desktop/energy_spectra.pdf", dpi=300, bbox_inches='tight')

# %%
# check the pre-pulse info

data = np.loadtxt("/Users/yao/Nextcloud/PROJECTS/ELI/Xray-April2025/Lucian/laser_info/1PWA_DB1PWA_1Hz_pre400_post10_AVG2_T100TWB_THG_rotated_AC20250218-1555-.dat",
                  skiprows=26,usecols=(0,1),)

time_ps  = data[:,0]
contrast = data[:,1]/np.max(data[:,1])

# %%
np.savetxt("/Users/yao/Desktop/pre_pulse_contrast.txt",
           np.column_stack((time_ps, contrast)))

# %%
width  = 3.487 * 2
height = width / 1.618 * 1.2

fig, ax = plt.subplots()
fig.subplots_adjust(left=.15, bottom=.16, right=.99, top=.97)

# experiment
ax.plot(time_ps, contrast,
        linestyle='-', linewidth=1,
        # marker='s', markersize=8, 
        # color='orange',
        label='measurement'
        )
ax.plot(time_ps, 0.5*np.ones_like(time_ps),
        linestyle='--', linewidth=1,
        label='0.5 contrast',)

ax.plot(time_ps, np.exp(-(time_ps-0.0543)**2/(2*0.0508**2)),
        linestyle=':', linewidth=1, color='k',
        label='fit: exp(-(t-0.0543)^2/(2*0.0508^2))')

ax.set_yscale('log')


ax.set_xlim([-0.5,0.5])
# ax.set_ylim([0,1])
# ax.set_xlim([-10,10])
ax.set_ylim([1e-6,1])
# ax.set_xlim([-400,50])
# ax.set_ylim([1e-12,1])
# ax.grid(linestyle='--',alpha=0.5)
ax.set_xlabel('Time (ps)')
ax.set_ylabel('Contrast')
ax.legend(fancybox=False, reverse=True, frameon=False)
ax.set_title('FWHM= 0.120 fs')
fig.set_size_inches(width, height)
fig.tight_layout()

# plt.show()

# plt.savefig("/Users/yao/Desktop/laser_contrast.pdf", dpi=300, bbox_inches='tight')

# %%
wkdir = [
     # '/Users/yao/Documents/Data/eli0/', # 2D, 15*0.7 J
     # '/Users/yao/Documents/Data/eli1/', # 2D, 15*0.3 J
     # '/Users/yao/Documents/Data/ELI2025/eli2', # 2D, 15*0.15 J, 150 nm SiN
     # '/Users/yao/Documents/Data/ELI2025/eli3', # 2D, 15*0.15 J,  30 nm SiN
     # '/Users/yao/Documents/Data/ELI2025/eli4_r*', # 2D, 15*0.15 J, 500 um SiN
     # '/Users/yao/Documents/Data/ELI2025/eli5_r*', # 2D, 500 nm + pre-plasmas
     # '/Users/yao/Documents/Data/ELI2025/eli6_30nm_pp', # 2D, 30 nm + pre-plasmas  
     # '/Users/yao/Desktop/eli_prepulse0', # test pre-pulse  
     # '/Users/yao/Desktop/eli_July17_1.5um/', # with pre-plasmas and [-500, 0] fs
     # '/Users/yao/Desktop/eli_July17_2um/', # with pre-plasmas and [-500, 0] fs
     # '/Users/yao/Desktop/eli_Aug04/eli_Aug04_2um/',
     # '/Users/yao/Desktop/eli_Aug04/eli_Aug04_0.8um/',
     '/Users/yao/Documents/Data/ELI2025/eli_Aug27_2um/',
     '/Users/yao/Desktop/test_sep5/',
     # '/Users/yao/Desktop/eli_Aug27_2um/',
     # '/Users/yao/Desktop/eli_Aug28_0.8um/',
     # '/Users/yao/Desktop/eli_Aug08/eli_Aug08_2um/',
     # '/Users/yao/Desktop/eli_Aug08/eli_Aug08_0.8um/',
     # '/Users/yao/Desktop/eli_Aug29_0.8um/',
     # '/Users/yao/Desktop/eli_Aug14_0.8um/',
    ]

# %%
S0 = happi.Open(wkdir[0], reference_angular_frequency_SI = 2.0*np.pi*3e8/(0.810*1e-6))
S1 = happi.Open(wkdir[1], reference_angular_frequency_SI = 2.0*np.pi*3e8/(0.810*1e-6))
# S2 = happi.Open(wkdir[2], reference_angular_frequency_SI = 2.0*np.pi*3e8/(0.810*1e-6))
# S3 = happi.Open(wkdir[3], reference_angular_frequency_SI = 2.0*np.pi*3e8/(0.810*1e-6))
# S4 = happi.Open(wkdir[4], reference_angular_frequency_SI = 2.0*np.pi*3e8/(0.810*1e-6))
# Out:
# I_0 = 1.5e+21 W/cm2
# a_0 =  26.88270100135983
# Loaded simulation '/Users/yao/Documents/Data/ELI2025/eli_Aug27_2um/'
# Scanning for Scalar diagnostics
# Scanning for Field diagnostics
# Scanning for Probe diagnostics
# Scanning for ParticleBinning diagnostics
# Scanning for RadiationSpectrum diagnostics
# Scanning for Performance diagnostics
# Scanning for Screen diagnostics
# Scanning for Tracked particle diagnostics
# Scanning for new particle diagnostics
# I_0 = 1.5e+21 W/cm2
# a_0 =  26.88270100135983
# Loaded simulation '/Users/yao/Desktop/test_sep5/'
# Scanning for Scalar diagnostics
# Scanning for Field diagnostics
# Scanning for Probe diagnostics
# Scanning for ParticleBinning diagnostics
# Scanning for RadiationSpectrum diagnostics
# Scanning for Performance diagnostics
# Scanning for Screen diagnostics
# Scanning for Tracked particle diagnostics
# Scanning for new particle diagnostics

# %%
# prepare constants, units

me = 9.1e-31
mp = 1836.*me
qe = 1.6e-19
ep = 8.9e-12  # epsilon_0
c  = 3.0e8
wr = S0.namelist.wr
de = c / wr
Lx = S0.namelist.Lsim[0].real / 2 / np.pi      # in um
dx = Lx/S0.namelist.resx           # in mm

Te = S0.namelist.temp_e * 511.e3             # in eV
ne = 1e20 #S0.namelist.n0                              # in cm-3
ld = 7.43e2 * Te**0.5 * ne**(-0.5) * 10. # in mm
dt = S0.namelist.Tsim / S0.namelist.rest

B0 = S0.namelist.B0 * (me * wr / qe)
wc = qe * B0 / me
print("B0 = ", B0)
# Out:
# B0 =  20.0

# %%
S0.Field(0,'Ey',units=['fs','um','V/m'],vsym=True).slide()
# Out:
# Field diagnostic #0: Ey
# 	Grid spacing: 0.39269908169872414, 0.39269908169872414

# %%
Ey1 = S0.Field(0,'Ey',units=['fs','um','V/m'],vsym=True)
Ey2 = S1.Field(0,'Ey',units=['fs','um','V/m'],vsym=True)

happi.multiSlide(Ey1, Ey2,shape=[2,1])

# %%
Ex0 = S0.Field(1,'Ex',units=['fs','um','V/m','T'],
        #  vsym=True, 
         vsym=1e13, 
        #  ymax=30,
         )#.slide(figure=2)

Ex1 = S1.Field(1,'Ex',units=['fs','um','V/m','T'],
        #  vsym=True,
         vsym=1e13, 
        #  ymax=30,
         )#.slide(figure=2)

happi.multiSlide(Ex0, Ex1,shape=[2,1])

# %%
Ex1 = S0.Field(1,'Ex',units=['fs','um','V/m'],vsym=True)
Ex2 = S1.Field(1,'Ex',units=['fs','um','V/m'],vsym=True)

happi.multiSlide(Ex1, Ex2,shape=[2,1])

# %%
Lx = S0.namelist.Lsim[0].real / 2 / np.pi      # in um
print("Lx = ", Lx)
Ly = S0.namelist.Lsim[1].real / 2 / np.pi      # in um
print("Ly = ", Ly)
# Out:
# Lx =  160.0
# Ly =  160.0

# %%
Ex0 = S0.Field(1,'Ex',units=['fs','um','V/m'],
               vsym=5e12,
               subset={'y':Ly/2},
               # subset={'y':640},
               color='blue',
               label='2 um',
               )#.slide(figure=3)

Ex1 = S1.Field(1,'Ex',units=['fs','um','V/m'],
               vsym=5e12,
               subset={'y':Ly/2},
               # subset={'y':640},
               color='red',
               linestyle='--',
                label='0.8 um',
               )#.slide(figure=3)

happi.multiSlide(Ex0, Ex1)

# %%
from numpy import array, arange

tr = 1./(2.*np.pi*3e8/0.810e-6)*1e15
print('tr = ', tr)

tstop = S0.namelist.Main.simulation_time*tr # simulation final time
tstep = S0.namelist.Main.timestep        # simulation timestep
times = arange(0., tstop, tstep)

laser = S0.namelist.Laser[0]
laser_profile = array([laser.time_envelope(t) for t in times])


plt.plot( times, laser_profile**2 / 2 )
# Out:
# tr =  0.42971834634811745

# %%
# number density distribution
# 0: proton-target; 1: Si; 2: eon; 3: eon2; 

np0 = S0.ParticleBinning('#1+#2', units=['fs','um','1/cm^3'],
                         data_log='True',
                        #  xmin=0,xmax=32,
                        #  ymin=0,ymax=32,
                         vmin=18,vmax=22,
                         cmap=newcmap,
                         aspect=1.0,
                        #  average={'y':'all'},
                  #  data_log='True',
                  #  color='red',
              # label='np: B=0',
              # linestyle='-'
                  #  xmin=0,xmax=32,
                #    sum={'px':'all'}
                   ).slide(figure=2)

# np1 = S1.ParticleBinning(0, units=['fs','um','1/cm^3'],
#                          data_log='True',
#                         #  xmin=0,xmax=32,
#                          ymin=0,ymax=32,
#                          vmin=18,vmax=22,
#                          cmap=newcmap,
#                          aspect=1.0,
#                         #  average={'y':'all'},
#                   #  data_log='True',
#                   #  color='red',
#               # label='np: B=0',
#               # linestyle='-'
#                   #  xmin=0,xmax=32,
#                 #    sum={'px':'all'}
#                    )


# # np0.set(set_layout_engine='tight')
# np0.set(aspect_ratio=1.0)
# # np0.set(set_label='n (cm$^{-3}$)')
# # np0.slide()
# happi.multiSlide(np1, np2, np3, np4, shape=(2,2))
# Out:
# #1 - Number density of species # 1,2
#     x from 0 to 1005.31 in 400 steps
#     y from 0 to 502.655 in 400 steps
#
# #2 - Number density of species # 4
#     x from 0 to 1005.31 in 400 steps
#     y from 0 to 502.655 in 400 steps
#
# Operation : #1+#2
# The value in each bin is the sum of the `deposited_quantity` divided by the bin size
# /Users/yao/Smilei/happi/_Diagnostics/Diagnostic.py:857: RuntimeWarning: divide by zero encountered in log10
#   return self._np.log10( self._dataLinAtTime(t) )

# %%
np0 = S0.ParticleBinning('#1+#2', units=['fs','um','1/cm^3'],
                         data_log='True',
                        #  ymin=0,ymax=32,
                         # vmin=18,vmax=23,
                         cmap=newcmap,
                         subset={'y':Ly/2},
                   color='blue',
              label='2 um',
                   )#.slide()

np1 = S1.ParticleBinning('#1+#2', units=['fs','um','1/cm^3'],
                         data_log='True',
                        #  ymin=0,ymax=32,
                         # vmin=18,vmax=23,
                         cmap=newcmap,
                         subset={'y':Ly/2},
                   color='red',
                   linestyle='--',
              label='0.8 um - 4 um',
                   )#.slide()

np2 = S2.ParticleBinning('#1+#2', units=['fs','um','1/cm^3'],
                         data_log='True',
                        #  ymin=0,ymax=32,
                         # vmin=17,vmax=23,
                         cmap=newcmap,
                         subset={'y':Ly/2},
                   color='orange',
                   linestyle=':',
              label='0.8 um - rear-plasma',
                   )#.slide()

happi.multiSlide(np0, np1, np2)

# %%
# electron number density distribution
S0.ParticleBinning("#1+#2", units=['fs','um','1/cm^3'],
                         data_log='True',
                        #  xmin=0,xmax=32,
                        #  ymin=0,ymax=32,
                         vmin=18,vmax=24,
                         cmap=newcmap,
                         aspect=1.0,
                        #  average={'y':'all'},
                  #  data_log='True',
                  #  color='red',
              # label='np: B=0',
              # linestyle='-'
                  #  xmin=0,xmax=32,
                #    sum={'px':'all'}
                   ).plot()
# Out:
# #1 - Number density of species # 1,2
#     x from 0 to 1005.31 in 400 steps
#     y from 0 to 502.655 in 400 steps
#
# #2 - Number density of species # 4
#     x from 0 to 1005.31 in 400 steps
#     y from 0 to 502.655 in 400 steps
#
# Operation : #1+#2
# The value in each bin is the sum of the `deposited_quantity` divided by the bin size

# %%
# Phase space distribution
# 4: proton-target; 5: Si; 6: eon; 7: eon2;

ps0 = S0.ParticleBinning('#4', units=['fs','um','1/cm^3'],
                   data_log='True',
                   cmap=newcmap,
                   vmin=-5,
                   vmax=1,
                  #  aspect=1.0,
                   xmin=0,xmax=32,
                   ymin=-200,ymax=600,
                   aspect='auto',
                  #  layout='tight',
                #    sum={'px':'all'}
                   )#.slide()

ps1 = S1.ParticleBinning('#4', units=['fs','um','1/cm^3'],
                   data_log='True',
                   cmap=newcmap,
                   vmin=-5,
                   vmax=1,
                  #  aspect=1.0,
                   xmin=0,xmax=32,
                   ymin=-200,ymax=600,
                   aspect='auto',
                  #  layout='tight',
                #    sum={'px':'all'}
                   )#.slide()

ps2 = S2.ParticleBinning('#4', units=['fs','um','1/cm^3'],
                   data_log='True',
                   cmap=newcmap,
                   vmin=-5,
                   vmax=1,
                  #  aspect=1.0,
                   xmin=0,xmax=32,
                   ymin=-200,ymax=600,
                   aspect='auto',
                  #  layout='tight',
                #    sum={'px':'all'}
                   )#.slide()

# ps0.set(set_layout_engine='tight')
# ps0.slide()

happi.multiSlide(ps0, ps1, ps2, shape=(3,1))

# %%
S0.ParticleBinning(3, units=['fs','um','1/cm^3'],
                   data_log='True',
                   cmap=newcmap,
                   vmin=-5,
                   vmax=1,
                  #  aspect=1.0,
                #    xmin=0,xmax=32,
                   ymin=-100,ymax=400,
                   aspect='auto',
                  #  layout='tight',
                #    sum={'px':'all'}
                   ).plot()
# Out:
# #3 - Number density of species # 5
#     x from 0 to 1005.31 in 400 steps
#     px from -400 to 800 in 400 steps
#
# The value in each bin is the sum of the `deposited_quantity` divided by the bin size and by grid_length[1]

# %%
S0.ParticleBinning("#4+#5", units=['fs','um','1/cm^3'],
                   data_log='True',
                   cmap=newcmap,
                   vmin=-5,
                   vmax=1,
                  #  aspect=1.0,
                #    xmin=0,xmax=32,
                   ymin=-25,ymax=25,
                   aspect='auto',
                  #  layout='tight',
                #    sum={'px':'all'}
                   ).slide()
# Out:
# #4 - Number density of species # 1,2
#     x from 0 to 1005.31 in 400 steps
#     px from -50 to 50 in 400 steps
#
# #5 - Number density of species # 4
#     x from 0 to 1005.31 in 400 steps
#     px from -50 to 50 in 400 steps
#
# Operation : #4+#5
# The value in each bin is the sum of the `deposited_quantity` divided by the bin size and by grid_length[1]
# /Users/yao/Smilei/happi/_Diagnostics/Diagnostic.py:857: RuntimeWarning: divide by zero encountered in log10
#   return self._np.log10( self._dataLinAtTime(t) )

# %%
# Phase space distribution electrons
# 4: proton-target; 5: Si; 6: eon; 7: eon2;

ps0 = S0.ParticleBinning('#6', units=['fs','um','1/cm^3'],
                   data_log='True',
                   cmap=newcmap,
                   vmin=-5,
                   vmax=1,
                  #  aspect=1.0,
                #    xmin=0,xmax=32,
                   ymin=-50,ymax=50,
                   aspect='auto',
                  #  layout='tight',
                #    sum={'px':'all'}
                   )#.slide()

ps1 = S1.ParticleBinning('#6', units=['fs','um','1/cm^3'],
                   data_log='True',
                   cmap=newcmap,
                   vmin=-5,
                   vmax=1,
                  #  aspect=1.0,
                #    xmin=0,xmax=32,
                   ymin=-50,ymax=50,
                   aspect='auto',
                  #  layout='tight',
                #    sum={'px':'all'}
                   )#.slide()

ps2 = S2.ParticleBinning('#6', units=['fs','um','1/cm^3'],
                   data_log='True',
                   cmap=newcmap,
                   vmin=-5,
                   vmax=1,
                  #  aspect=1.0,
                #    xmin=0,xmax=32,
                   ymin=-50,ymax=50,
                   aspect='auto',
                  #  layout='tight',
                #    sum={'px':'all'}
                   )#.slide()

# ps0.set(set_layout_engine='tight')
# ps0.slide()

happi.multiSlide(ps0, ps1, ps2, shape=(3,1))

# %%
es0 = S0.ParticleBinning('#6', units=['fs','um','1/cm^3','MeV'],
                   data_log='True',
                   xmin=0,xmax=35,
                #    vmin=-7,vmax=-2,
                timestep_indices=105,
                   color='blue',
                   label='40 um',
                   linestyle='-',
                   )#.slide()

es1 = S1.ParticleBinning('#6', units=['fs','um','1/cm^3','MeV'],
                   data_log='True',
                   xmin=0,xmax=35,
                   timestep_indices=105,
                #    vmin=-7,vmax=-2,
                   color='red',
                   label='24 um',
                   linestyle='--',
                   )#.slide()

# es2 = S2.ParticleBinning('#6', units=['fs','um','1/cm^3','MeV'],
#                    data_log='True',
#                    xmin=0,xmax=30,
#                 #    vmin=-7,vmax=-2,
#                    color='orange',
#                    label='0.8 um',
#                    linestyle=':',
#                    )#.slide()
happi.multiPlot(es0, es1,skipAnimation=True,
                saveAs="/Users/yao/Desktop/p_spectrum.pdf",dpi=300)

# happi.multiSlide(es0, es1)#, es2)
# Out:
# /Users/yao/Smilei/happi/_Diagnostics/Diagnostic.py:857: RuntimeWarning: divide by zero encountered in log10
#   return self._np.log10( self._dataLinAtTime(t) )

# %%
es0 = S0.ParticleBinning('#7+#8', units=['fs','um','1/cm^3','MeV'],
                   data_log='True',
                   xmin=0,xmax=50,
                #    vmin=-7,vmax=-2,
                   color='blue',
                   label='2 um',
                   linestyle='-',
                   )#.slide()

es1 = S1.ParticleBinning('#7+#8', units=['fs','um','1/cm^3','MeV'],
                   data_log='True',
                   xmin=0,xmax=50,
                #    vmin=-7,vmax=-2,
                   color='red',
                   label='0.8 um',
                   linestyle='--',
                   )#.slide()
happi.multiPlot(es0, es1,timesteps=1165,skipAnimation=True,
                saveAs="/Users/yao/Desktop/p_spectrum.pdf",dpi=300)
# happi.multiSlide(es0, es1)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/Smilei/happi/_Diagnostics/ParticleBinning.py:47, in ParticleBinning._init(self, diagNumber, timesteps, subset, average, sum, data_log, data_transform, include, **kwargs)
#      46 info = self._getInfo(self.simulation, self._diagType, d)
# ---> 47 if info is False: raise
#      48 self._myinfo.update({ d:info })
#
# RuntimeError: No active exception to reraise
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 10
#       1 es0 = S0.ParticleBinning('#7+#8', units=['fs','um','1/cm^3','MeV'],
#       2                    data_log='True',
#       3                    xmin=0,xmax=50,
#    (...)      7                    linestyle='-',
#       8                    )#.slide()
# ...

# %%
es0 = S0.Screen('#0', units=['fs','um','1/cm^3','MeV'],
                   data_log='True',
                   xmin=0,xmax=100,
                  #  vmin=-8,vmax=1,
                   color='blue',
                   label='2.0 um',
                   linestyle='-',
                   ).plot()

# es1 = S1.Screen('#0', units=['fs','um','1/cm^3','MeV'],
#                    data_log='True',
#                    xmin=0,xmax=100,
#                   #  vmin=-8,vmax=0,
#                    color='red',
#                    label='0.8 um',
#                    linestyle='--',
#                    )#.plot()

# happi.multiSlide(es0, es1)
# Out:
# #0 - Number density of species # 1,2,4
#     ekin from 0.000195695 to 195.695 in 10000 steps
#
# The value in each bin is the sum of the `deposited_quantity` divided by the bin size and by grid_length[0] * grid_length[1]

# %%
S0.Screen('#2', units=['fs','um','1/cm^3','MeV'],
                   data_log='True',
                   xmin=0,xmax=50,
                   vmin=-8,vmax=0,
                   color='red',
                #    label='150 nm SiN',
                   linestyle='-',
                   ).slide()
# Out:
# #2 - Number density of species # 5
#     ekin from 0.000195695 to 97.8474 in 10000 steps
#
# The value in each bin is the sum of the `deposited_quantity` divided by the bin size and by grid_length[0] * grid_length[1]

# %%
# energy spectrum binning for protons
# 8: proton-target; 9: Si; 10: eon; 11: eon2;

es_p0 = S0.ParticleBinning('#6', units=['fs','um','1/cm^3','MeV'],
                   data_log='True',
                   xmin=0,xmax=30,
                #    vmin=-7,vmax=-2,
                   color='blue',
                   label='1.5',
                   linestyle='-',
                   )#.slide()

es_p1 = S1.ParticleBinning('#6', units=['fs','um','1/cm^3','MeV'],
                   data_log='True',
                   xmin=0,xmax=30,
                #    vmin=-7,vmax=-2,
                   color='red',
                   label='2.0',
                   linestyle='-',
                   )#.slide()

happi.multiSlide(es_p0, es_p1)

# %%
# energy spectrum binning for electrons
# 8: proton-target; 9: Si; 10: eon; 11: eon2;

es_p0 = S0.ParticleBinning('#10+#11', units=['fs','um','1/cm^3','MeV'],
                   data_log='True',
                   xmin=0,xmax=50,
                #    vmin=-7,vmax=-2,
                   color='red',
                   label='150 nm SiN',
                   linestyle='-',
                   )#.slide()

es_p1 = S1.ParticleBinning('#10+#11', units=['fs','um','1/cm^3','MeV'],
                   data_log='True',
                   xmin=0,xmax=50,
                #    vmin=-7,vmax=-2,
                   color='blue',
                   label='30 nm SiN',
                   linestyle='-',
                   )#.slide()

es_p2 = S2.ParticleBinning('#10+#11', units=['fs','um','1/cm^3','MeV'],
                   data_log='True',
                   xmin=0,xmax=50,
                #    vmin=-7,vmax=-2,
                   color='black',
                   label='500 nm SiN',
                   linestyle='-',
                   )#.slide()

es_p3 = S3.ParticleBinning('#10+#11', units=['fs','um','1/cm^3','MeV'],
                   data_log='True',
                   xmin=0,xmax=50,
                #    vmin=-7,vmax=-2,
                   color='black',
                   label='500 nm SiN + pp',
                   linestyle=':',
                   )#.slide()

es_p4 = S4.ParticleBinning('#10+#11', units=['fs','um','1/cm^3','MeV'],
                   data_log='True',
                   xmin=0,xmax=50,
                #    vmin=-7,vmax=-2,
                   color='blue',
                   label='30 nm SiN + pp',
                   linestyle=':',
                   )#.slide()




happi.multiSlide(es_p0, es_p1, es_p2, es_p3, es_p4)

# %%
num0 = np.array(S0.ParticleBinning(6, units=['fs','um','1/cm^3','MeV'],).getData()[-2])
ekin0 = np.array(S0.ParticleBinning(6, units=['fs','um','1/cm^3','MeV'],).getAxis('ekin'))

num1 = np.array(S1.ParticleBinning(6, units=['fs','um','1/cm^3','MeV'],).getData()[-2])
ekin1 = np.array(S1.ParticleBinning(6, units=['fs','um','1/cm^3','MeV'],).getAxis('ekin'))

# num2 = np.array(S2.ParticleBinning(8, units=['fs','um','1/cm^3','MeV'],).getData()[-1])
# ekin2 = np.array(S2.ParticleBinning(8, units=['fs','um','1/cm^3','MeV'],).getAxis('ekin'))

# num3 = np.array(S3.ParticleBinning(8, units=['fs','um','1/cm^3','MeV'],).getData()[-1])
# ekin3 = np.array(S3.ParticleBinning(8, units=['fs','um','1/cm^3','MeV'],).getAxis('ekin'))

# num4 = np.array(S4.ParticleBinning(8, units=['fs','um','1/cm^3','MeV'],).getData()[-1])
# ekin4 = np.array(S4.ParticleBinning(8, units=['fs','um','1/cm^3','MeV'],).getAxis('ekin'))

# %%
nume0 = np.array(S0.Screen(0, units=['fs','um','1/cm^3','MeV'],).getData()[-1])
ekine0 = np.array(S0.Screen(0, units=['fs','um','1/cm^3','MeV'],).getAxis('ekin'))

nume1 = np.array(S1.Screen(0, units=['fs','um','1/cm^3','MeV'],).getData()[-1])
ekine1 = np.array(S1.Screen(0, units=['fs','um','1/cm^3','MeV'],).getAxis('ekin'))

# %%
np.savetxt("/Users/yao/Desktop/e_spectrum_2um_num.txt", nume1*3e13)
np.savetxt("/Users/yao/Desktop/e_spectrum_2um_ene.txt", ekine1)

# %%
## estimate the total number of electrons

import numpy as np
from scipy import integrate          # only needed for Simpson
E     = ekine1        # MeV
dNdE  = nume1*3e13   # electrons per MeV

N_trapz  = np.trapz(dNdE, E)         # 6.153e13
# N_simps  = integrate.simps(dNdE, E)  # 5.157e13  (optional)

print(f"N_total (trapz)  = {N_trapz:.3e}")
# print(f"N_total (Simpson)= {N_simps:.3e}")
# Out:
# N_total (trapz)  = 2.181e+11
# /var/folders/2t/97rc3fl92tg15k2l_4sk5hsh0000gn/T/ipykernel_59777/1784141462.py:8: DeprecationWarning: `trapz` is deprecated. Use `trapezoid` instead, or one of the numerical integration functions in `scipy.integrate`.
#   N_trapz  = np.trapz(dNdE, E)         # 6.153e13

# %%
S1.ParticleBinning(9, units=['fs','um','1/cm^3','MeV','MeV cm^-3'],
                   data_log='True',
                   cmap=newcmap,
                #    ymin=0,ymax=50,
                   vmin=16,
                   vmax=22,
                   aspect=1.0,
                #    xmin=0,xmax=32,
                #    ymin=-200,ymax=600,
                #    aspect='auto',
                #    layout='tight',
                  #  sum={'ekin':[0,1]},
                   sum={'ekin':[2,10]},
                     # sum={'y':'all'},
                  ).slide()

# %%
num0 = np.array(S0.Screen(2, units=['fs','um','1/cm^3','MeV'],).getData()[-1])
ekin0 = np.array(S0.Screen(2, units=['fs','um','1/cm^3','MeV'],).getAxis('ekin'))

num1 = np.array(S1.Screen(2, units=['fs','um','1/cm^3','MeV'],).getData()[-1])
ekin1 = np.array(S1.Screen(2, units=['fs','um','1/cm^3','MeV'],).getAxis('ekin'))

num2 = np.array(S2.Screen(2, units=['fs','um','1/cm^3','MeV'],).getData()[-1])
ekin2 = np.array(S2.Screen(2, units=['fs','um','1/cm^3','MeV'],).getAxis('ekin'))

# %%
plt.semilogy(ekin0,num0)

# %%
width  = 3.487 * 2
height = width / 1.618 * 1.2

fig, ax = plt.subplots()
fig.subplots_adjust(left=.15, bottom=.16, right=.99, top=.97)

ax.plot(ekin0[::2], num0[::2]*3e13,
        linestyle='--', 
        # marker='^', markersize=8, 
        color='blue',
        linewidth=1,
        label='PIC 1.5 um Al')

ax.plot(ekin1[::2], num1[::2]*3e13,
        linestyle='--', 
        # marker='^', markersize=8, 
        color='red',
        linewidth=1,
        label='PIC 2.0 um Al')

# experiment
# ax.plot(exp_energy_nodpm, exp_number_nodpm,
#         linestyle=':', linewidth=1,
#         # marker='s', markersize=8, 
#         color='orange',
#         label='Apollon 1.5 um Al')

# ax.plot(exp_energy_dpm, exp_number_dpm,
#         linestyle=':', linewidth=1,
#         # marker='s', markersize=8, 
#         color='green',
#         label='Apollon 200 nm SiN')

ax.set_yscale('log')

ax.plot(shot16[:,1], shot16[:,0],
        linestyle='-', marker='o', markersize=8, color='red',
        linewidth=2,
        label='EXP 30 nm SiN')

ax.plot(shot17[:,1], shot17[:,0],
        linestyle='-', marker='*', markersize=8, color='orange',
        linewidth=2,
        label='EXP 150 nm SiN')

ax.plot(shot43[:,1], shot43[:,0],
        linestyle='-', marker='v', markersize=8, color='purple',
        linewidth=2,
        label='EXP 500 nm SiN')


ax.plot(shot20[:,1], shot20[:,0],
        linestyle='-', marker='s', markersize=8, color='blue',
        linewidth=2,
        label='EXP 10 um Au')



# ax.plot(ekin1[::5], num1[::5]*1e14,
#         linestyle='-', 
#         # marker='^', markersize=8, 
#         color='cyan',
#         linewidth=2,
#         label='PIC Simu. for 30 nm SiN')

# ax.plot(ekin2[::5], num2[::5]*1e14,
#         linestyle='-', 
#         # marker='^', markersize=8, 
#         color='magenta',
#         linewidth=2,
#         label='PIC Simu. for 500 nm SiN')


ax.set_xlim([0,30])
# ax.set_ylim([1e6,1e12])
ax.grid(linestyle='--',alpha=0.5)
ax.set_xlabel('Energy (MeV)')
ax.set_ylabel('dN/dE (No./MeV)')
ax.legend(fancybox=False, reverse=True, frameon=False)
fig.set_size_inches(width, height)
fig.tight_layout()

# plt.show()

# plt.savefig("/Users/yao/Desktop/energy_spectra.png", dpi=300, bbox_inches='tight')

# %%
width  = 3.487 * 2
height = width / 1.618 * 1.2

fig, ax = plt.subplots()
fig.subplots_adjust(left=.15, bottom=.16, right=.99, top=.97)

factor = 1e15

ax.plot(ekine0[::2], nume0[::2]*factor,
        linestyle='--', 
        # marker='^', markersize=8, 
        color='blue',
        linewidth=2,
        label='40 um')

ax.plot(ekine1[::2], nume1[::2]*factor,
        linestyle='--', 
        # marker='^', markersize=8, 
        color='red',
        linewidth=2,
        label='24 um')

ax.set_yscale('log')

ax.plot(ene105, num105, linestyle='-', color='green', label="#105, 30 nm")
ax.plot(ene102, num102, linestyle='-', color='cyan', label="#102, 150 nm")
ax.plot(ene8081, num8081, linestyle='-', color='orange', label="#80-81, 2 um Au")
ax.plot(ene7879, num7879, linestyle='-', color='purple', label="#78-79, 3 um Au")
ax.plot(ene7273, num7273, linestyle='-', color='brown', label="#72-73, 10 um Au")
ax.plot(ene7475, num7475, linestyle='-', color='black', label="#74-75, 25 um W")
ax.plot(ene7677, num7677, linestyle='-', color='grey', label="#76-77, 50 um Au")


# plt.xlim(0, 60)
# plt.ylim(1e8, 2e11)



ax.set_xlim([0,60])
ax.set_ylim([1e8,2e11])
ax.grid(linestyle='--',alpha=0.5)
ax.set_xlabel('Energy (MeV)')
ax.set_ylabel('dN/dE (No./MeV)')
ax.legend(fancybox=False, reverse=True, frameon=False, fontsize=12)
fig.set_size_inches(width, height)
fig.tight_layout()

# plt.show()

plt.savefig("/Users/yao/Desktop/e_spectra.pdf", dpi=300, bbox_inches='tight')

# %%
width  = 3.487 * 2
height = width / 1.618 * 1.2

fig, ax = plt.subplots()
fig.subplots_adjust(left=.15, bottom=.16, right=.99, top=.97)

# experiment
# ax.plot(exp_energy_nodpm, exp_number_nodpm,
#         linestyle=':', linewidth=1,
#         # marker='s', markersize=8, 
#         color='orange',
#         label='Apollon 1.5 um Al')

# ax.plot(exp_energy_dpm, exp_number_dpm,
#         linestyle=':', linewidth=1,
#         # marker='s', markersize=8, 
#         color='green',
#         label='Apollon 200 nm SiN')

ax.set_yscale('log')

# ax.plot(shot16[:,1], shot16[:,0],
#         linestyle='-', marker='o', markersize=8, color='black',
#         linewidth=2,
#         label='EXP 30 nm SiN')

# ax.plot(shot17[:,1], shot17[:,0],
#         linestyle='-', marker='*', markersize=8, color='red',
#         linewidth=2,
#         label='EXP 150 nm SiN')

ax.plot(shot43[:,1], shot43[:,0],
        linestyle='-', marker='v', markersize=8, color='blue',
        linewidth=2,
        label='EXP 500 nm SiN')


# ax.plot(shot20[:,1], shot20[:,0],
#         linestyle='--', marker='s', markersize=8, color='blue',
#         linewidth=2,
#         label='ELI 10 um Au')

# ax.plot(ekin0[::5], num0[::5]*1.5e14,
#         linestyle='--', 
#         # marker='^', markersize=8, 
#         color='red',
#         linewidth=1,
#         label='SIM 150 nm SiN')

# ax.plot(ekin1[::5], num1[::5]*6e13,
#         linestyle='--', 
#         # marker='^', markersize=8, 
#         color='black',
#         linewidth=1,
#         label='PIC Simu. for 30 nm SiN')

# ax.plot(ekin4[::5], num4[::5]*6e13,
#         linestyle=':', 
#         # marker='^', markersize=8, 
#         color='black',
#         linewidth=1,
#         label='PIC Simu. for 30 nm SiN + pp')

ax.plot(ekin2[::5], num2[::5]*6e13,
        linestyle='--', 
        # marker='^', markersize=8, 
        color='blue',
        linewidth=1,
        label='SIM 500 nm SiN')

ax.plot(ekin3[::5], num3[::5]*3e13,
        linestyle=':', 
        # marker='^', markersize=8, 
        color='blue',
        linewidth=1,
        label='SIM 500 nm SiN + pp')


ax.set_xlim([0,50])
ax.set_ylim([1e6,1e12])
ax.grid(linestyle='--',alpha=0.5)
ax.set_xlabel('Energy (MeV)')
ax.set_ylabel('dN/dE (No./MeV)')
ax.legend(fancybox=False, reverse=True, frameon=False)
fig.set_size_inches(width, height)
fig.tight_layout()

# plt.show()

# plt.savefig("/Users/yao/Desktop/energy_spectra_30_SiN.png", dpi=300, bbox_inches='tight')

# %%
sc00 = S0.Screen(0,units=['fs','um','1/cm^3','MeV'],
        #   xmin=3,xmax=10,
        color='red',
        #   vmin=-7,vmax=-5,
          data_log=True)#.slide()

sc01 = S0.Screen(1,units=['fs','um','1/cm^3','MeV'],
        #   xmin=3,xmax=10,
          color='blue',
        #   vmin=-7,vmax=-5,
          data_log=True)

happi.multiSlide(sc00, sc01)

# %%
screen_position = 0

num0  = np.array(S0.Screen(screen_position, units=['fs','um','1/cm^3','MeV'],).getData()[-1])
ekin0 = np.array(S0.Screen(screen_position, units=['fs','um','1/cm^3','MeV'],).getAxis('ekin'))

num1  = np.array(S1.Screen(screen_position, units=['fs','um','1/cm^3','MeV'],).getData()[-1])
ekin1 = np.array(S1.Screen(screen_position, units=['fs','um','1/cm^3','MeV'],).getAxis('ekin'))

num4  = np.array(S4.Screen(screen_position, units=['fs','um','1/cm^3','MeV'],).getData()[-1])
ekin4 = np.array(S4.Screen(screen_position, units=['fs','um','1/cm^3','MeV'],).getAxis('ekin'))

# %%
width  = 3.487 * 3
height = width / 1.618 

fig, ax = plt.subplots()
fig.subplots_adjust(left=.15, bottom=.16, right=.99, top=.97)

# experiment

# # Create the plot
# plt.figure(figsize=(8, 6))
# plt.plot(ene105, num105, linestyle='-', color='red', label="#105, 30 nm")
# plt.plot(ene102, num102, linestyle='--', color='blue', label="#102, 150 nm")
# # plt.title("Gray Value vs Distance")
# plt.xlabel("Energy (MeV)")
# plt.ylabel("dN/dE (a.u.)")
# plt.legend()
# # plt.grid(True)
# plt.yscale('log')
# plt.tight_layout()

# plt.xlim(0, 50)
# plt.ylim(1e8, 1e11)
# plt.show()

ax.plot(ene102, num102,
        linestyle='-', marker='*', markersize=8, color='orange',
        linewidth=2,
        label='EXP 150 nm (#102)')

ax.plot(ene105, num105,
        linestyle='-', marker='o', markersize=8, color='red',
        linewidth=2,
        label='EXP 30 nm (#105)')

ax.plot(ekin0[::5], num0[::5]*1e16,
        linestyle=':', 
        # marker='^', markersize=8, 
        color='orange',
        linewidth=2,
        label='PIC 150 nm')

ax.plot(ekin1[::5], num1[::5]*1e16,
        linestyle=':', 
        # marker='^', markersize=8, 
        color='cyan',
        linewidth=2,
        label='PIC 30 nm SiN')

ax.plot(ekin4[::5], num4[::5]*1e16,
        linestyle='--', 
        # marker='^', markersize=8, 
        color='magenta',
        linewidth=2,
        label='PIC 30 nm SiN + pp')


ax.set_xlim([0,50])
ax.set_ylim([1e8, 1e11])
ax.grid(linestyle='--',alpha=0.5)
ax.set_xlabel('Energy (MeV)')
ax.set_ylabel('dN/dE (No./MeV)')
ax.set_yscale('log')
ax.legend(fancybox=False, reverse=True, frameon=False)
fig.set_size_inches(width, height)
fig.tight_layout()

# plt.show()

# plt.savefig("/Users/yao/Desktop/energy_spectra.png", dpi=300, bbox_inches='tight')

# %%
# energy spectrum screening for electrons
# 0: electron right edge; 1: electron middle; 2: proton middle;

screen_num = 2

es_p0 = S0.Screen(screen_num, units=['fs','um','1/cm^3','MeV'],
                   data_log='True',
                   xmin=0,xmax=50,
                #    vmin=-7,vmax=-2,
                   color='red',
                   label='150 nm SiN',
                   linestyle='-',
                   )#.slide()

es_p1 = S1.Screen(screen_num, units=['fs','um','1/cm^3','MeV'],
                   data_log='True',
                   xmin=0,xmax=50,
                #    vmin=-7,vmax=-2,
                   color='blue',
                   label='30 nm SiN',
                   linestyle='--',
                   )#.slide()

es_p2 = S2.Screen(screen_num, units=['fs','um','1/cm^3','MeV'],
                   data_log='True',
                   xmin=0,xmax=50,
                #    vmin=-7,vmax=-2,
                   color='black',
                   label='500 nm SiN',
                   linestyle='-.',
                   )#.slide()

happi.multiPlot(es_p0, es_p1, es_p2, skipAnimation=True)

# %%
from PIL import Image

dir = '/Users/yao/Nextcloud/PROJECTS/ELI/Xray-April2025/Data_ELI_E5_Xray_2025/'
im0 = Image.open(dir+'RCF_23042025_03_just_layer11_bkg_removed.tif')
im1 = Image.open(dir+'RCF_24042025_16_just_layer11_bkg_removed.tif')

imarray0 = np.array(im0)
imarray1 = np.array(im1)

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable


width  = 3.487
height = width / 1.618 #* 1.5

fig, ax = plt.subplots()
fig.subplots_adjust(left=.15, bottom=.16, right=.99, top=.97)
divider = make_axes_locatable(ax)
cax = divider.append_axes('right', size='5%', pad=0.05)

yekin = ax.imshow(
                #   imarray0_OD_bg,#/np.max(imarray2),
                  # np.flipud(imarray0),
                  np.flipud(np.fliplr(imarray1)),
    # np.log10(imarray0_OD_bg/np.max(imarray2_OD_bg)), 
       #     cmap='magma',
                #   cmap=newcmap,
                  cmap='viridis_r',
           origin='lower',
           # extent=[-6, 6, -6, 6],
           vmin=0,
           vmax=6000,
           aspect='equal',
          )
cbar = fig.colorbar(yekin, cax=cax)
cbar.minorticks_on()
# cbar.cmap.set_under('white')
# cbar.set_ticks([0.94, 0.96, 0.98, 1.00])
# cbar.set_ticks([0.94, 0.95, 0.96])
# ax.set_xlim(-6,6)
ax.set_xticks([ ])
ax.set_yticks([ ])

# ax.get_xaxis().set_visible(False)
# ax.get_yaxis().set_visible(False)
# ax.axis('off')
# plt.axis('off')
# ax.set_ylim(-6,6)
# ax.set_yticks([ ])
# ax.set_xlabel(r'x ($\mu$m)')
# ax.set_ylabel(r'y ($\mu$m)')
# ax.set_title('Shot 257 (50 nm)', fontsize=16)
# ax.set_title('Shot 256 (10 nm)', fontsize=16)
# ax.set_title('Shot 82 (Calib.)', fontsize=16)
# ax.grid(linestyle='--',color='grey',alpha=0.5)
fig.set_size_inches(width, height)
fig.tight_layout()
fig.savefig('/Users/yao/Desktop/RCF_24042025_16_just_layer11_bkg_removed.pdf', dpi=600, bbox_inches='tight')
